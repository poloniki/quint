# %%
# !pip install ruptures
# Out:
# Collecting ruptures
#   Downloading ruptures-1.1.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 3.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy in /home/poloniki/.pyenv/versions/3.8.12/envs/quint/lib/python3.8/site-packages (from ruptures) (1.21.0)
# Requirement already satisfied: scipy in /home/poloniki/.pyenv/versions/3.8.12/envs/quint/lib/python3.8/site-packages (from ruptures) (1.9.1)
# Installing collected packages: ruptures
# Successfully installed ruptures-1.1.7

# %%
from pathlib import Path

import nltk
import numpy as np
import ruptures as rpt  # our package
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import regexp_tokenize
from ruptures.base import BaseCost
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.colors import LogNorm# Start writing code here...

# %%
180/100
# Out:
# 1.8

# %%
nltk.download("stopwords")
STOPWORD_SET = set(
    stopwords.words("english")
)  # set of stopwords of the English language
PUNCTUATION_SET = set("!\"#$%&'()*+,-./:;<=>?@[\\]^_`{|}~")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/poloniki/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def preprocess(list_of_sentences: list) -> list:
    """Preprocess each sentence (remove punctuation, stopwords, then stemming.)"""
    transformed = list()
    for sentence in list_of_sentences:
        ps = PorterStemmer()
        list_of_words = regexp_tokenize(text=sentence.lower(), pattern="\w+")
        list_of_words = [
            ps.stem(word) for word in list_of_words if word not in STOPWORD_SET
        ]
        transformed.append(" ".join(list_of_words))
    return transformed

# %%
def draw_square_on_ax(start, end, ax, linewidth=0.8):
    """Draw a square on the given ax object."""
    ax.vlines(
        x=[start - 0.5, end - 0.5],
        ymin=start - 0.5,
        ymax=end - 0.5,
        linewidth=linewidth,
    )
    ax.hlines(
        y=[start - 0.5, end - 0.5],
        xmin=start - 0.5,
        xmax=end - 0.5,
        linewidth=linewidth,
    )
    return ax

# %%
with open('../quint/data/sample_texts/joe_rogan_tr.txt') as f:
    doc = f.readlines()

# %%
doc = doc[0].replace("?", ".")

# %%
original_text = doc.split('.')

# %%
# transform text
transformed_text = preprocess(original_text)
# print original and transformed
ind = 3
print("Original sentence:")
print(f"\t{original_text[ind]}")
print()
print("Transformed:")
print(f"\t{transformed_text[ind]}")
# Out:
# Original sentence:
# 	 And things like that
#
# Transformed:
# 	thing like

# %%
# Once the text is preprocessed, each sentence is transformed into a vector of word counts.
#vectorizer = CountVectorizer(analyzer="word")
vectorizer = TfidfVectorizer(min_df=5, max_df=95, ngram_range=(1, 3), stop_words="english")

vectorized_text = vectorizer.fit_transform(transformed_text)

msg = f"There are {len(vectorizer.get_feature_names())} different words in the corpus, e.g. {vectorizer.get_feature_names()[20:30]}."
print(msg)
# Out:
# There are 522 different words in the corpus, e.g. ['american', 'american peopl', 'anoth', 'answer', 'anybodi', 'anymor', 'anyth', 'app', 'appear', 'appli'].
# /home/poloniki/.pyenv/versions/3.8.12/envs/quint/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
class CosineCost(BaseCost):
    """Cost derived from the cosine similarity."""

    # The 2 following attributes must be specified for compatibility.
    model = "custom_cosine"
    min_size = 2

    def fit(self, signal):
        """Set the internal parameter."""
        self.signal = signal
        self.gram = cosine_similarity(signal, dense_output=False)
        return self

    def error(self, start, end) -> float:
        """Return the approximation cost on the segment [start:end].

        Args:
            start (int): start of the segment
            end (int): end of the segment
        Returns:
            segment cost
        Raises:
            NotEnoughPoints: when the segment is too short (less than `min_size` samples).
        """
        if end - start < self.min_size:
            raise NotEnoughPoints
        sub_gram = self.gram[start:end, start:end]
        val = sub_gram.diagonal().sum()
        val -= sub_gram.sum() / (end - start)
        return val

# %%
#n_bkps = 9  # there are 9 change points (10 text segments)

#algo = rpt.Dynp(custom_cost=CosineCost(), min_size=2, jump=1).fit(vectorized_text)
algo = rpt.Pelt(custom_cost=CosineCost(), min_size=3, jump=1).fit(vectorized_text)

#predicted_bkps = algo.predict(n_bkps=n_bkps)
predicted_bkps = algo.predict(pen=1.5)

#print(f"True change points are\t\t{TRUE_BKPS}.")
print(f"Detected change points are\t{predicted_bkps}.")
# Out:
# Detected change points are	[48, 51, 125, 130, 221, 224, 255, 258, 345, 348, 440, 447, 470, 474, 481, 522, 526, 619, 622, 688, 691, 706, 740, 746, 777, 780, 816, 819, 839, 870, 873, 904, 911, 917, 947, 952, 981, 990, 994, 1070, 1088, 1101, 1150, 1156, 1219, 1222, 1228, 1233, 1315, 1319, 1377, 1395, 1398, 1435, 1440, 1489, 1492, 1497, 1501, 1519, 1522, 1526, 1555, 1558, 1585, 1589, 1661, 1675, 1720, 1731, 1745, 1748, 1762, 1765, 1809, 1812, 1834, 1842, 1851, 1859, 1879, 1882, 1889].

# %%
print(f"Detected change points are\t{predicted_bkps}.")
# Out:
# Detected change points are	[740, 743, 1228, 1233, 1591, 1720, 1731, 1851, 1859, 1889].

# %%
true_segment_list = rpt.utils.pairwise([0] + TRUE_BKPS)
predicted_segment_list = rpt.utils.pairwise([0] + predicted_bkps)

for (n_paragraph, (true_segment, predicted_segment)) in enumerate(
    zip(true_segment_list, predicted_segment_list), start=1
):
    print(f"Paragraph n°{n_paragraph:02d}")
    start_true, end_true = true_segment
    start_pred, end_pred = predicted_segment

    start = min(start_true, start_pred)
    end = max(end_true, end_pred)
    msg = " ".join(
        f"{ind+1:02d}" if (start_true <= ind < end_true) else "  "
        for ind in range(start, end)
    )
    print(f"(true)\t{msg}")
    msg = " ".join(
        f"{ind+1:02d}" if (start_pred <= ind < end_pred) else "  "
        for ind in range(start, end)
    )
    print(f"(pred)\t{msg}")
    print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/poloniki/code/poloniki/quint/notebooks/Change point detection.ipynb Cell 15 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/poloniki/code/poloniki/quint/notebooks/Change%20point%20detection.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> true_segment_list = rpt.utils.pairwise([0] + TRUE_BKPS)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/poloniki/code/poloniki/quint/notebooks/Change%20point%20detection.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> predicted_segment_list = rpt.utils.pairwise([0] + predicted_bkps)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/poloniki/code/poloniki/quint/notebooks/Change%20point%20detection.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> for (n_paragraph, (true_segment, predicted_segment)) in enumerate(
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/poloniki/code/poloniki/quint/notebooks/Change%20point%20detection.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>     zip(true_segment_list, predicted_segment_list), start=1
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/poloniki/code/poloniki/quint/notebooks/Change%20point%20detection.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> ):
#
# NameError: name 'TRUE_BKPS' is not defined

# %%
df['Topics']

# %%
for (start, end) in rpt.utils.pairwise([0] + predicted_bkps):
    excerpt = original_text[start:end]
    for (n_line, sentence) in enumerate(excerpt, start=start + 1):
        sentence = sentence.strip("\n")
        print(f"{n_line:>2}: {sentence}")
    print()
# Out:
#  1: Okay
#  2:  You're very professional
#  3:  People are like, how do you live
#  4:  And things like that
#  5:  They're taking money from the russians
#  6:  And of course the answer is no, but I do this for a living, like I speak
#  7:  I don't have a YouTube channel where I'm joe rogan, but I give speeches at universities and things like that
#  8:  I do a lot of interviews
#  9:  We're recording now, right
# 10:  My own setup
# 11:  Is it possible that you could do a YouTube channel
# 12:  Would that work
# 13:  Yeah, if you introduce me so I get followers
# 14:  Yeah, we could do that, dude, I'm all in
# 15:  That could absolutely happen
# 16:  Do you want to do that
# 17:  Is that something you want to do
# 18:  No
# 19:  I mean, this is a big question
# 20:  So I came on because I had just written a book called permanent record, which is the story of my life, because that's what publishers make you do when you're writing your first book
# 21:  But it's more than that, because I didn't just want to talk about me
# 22:  It's actually about the changing of technology and the changing of government in this sort of post 911 era, which our generation just sort of happened to be growing up during
# 23:  And I was at the CIA and the NSA and all this stuff, but the day that the book came out, the government hit me with a lawsuit, and they hit the publisher of the books with a lawsuit because they don't want to see books like this get written
# 24:  They especially don't want to see books like this get read
# 25:  And so the big thing was, we didn't know where this is going
# 26:  We didn't know what was going to happen
# 27:  And my publisher, of course, wanted me very badly to let people know this book existed in case the government leaned harder and harder and harder
# 28:  We didn't know where that's going
# 29:  The government is still pursuing that case quite strongly
# 30:  They're more focused on the financial censorship side of it, basically taking any money that I made from it kind of as a warning to the others and getting a legal judgment against the publishers saying, you can't pay this guy, that kind of thing more so than taking the book off the shelves
# 31:  But that's not because they're okay with the book being on the shelves
# 32:  It's because, thankfully we've got the first amendment, and so they can't and that's a very rare and good thing
# 33:  But anyway, in the context of that, they were like, well, what about Joe rogan
# 34:  And I had heard about you at this point, but the only thing that I had really seen, that I really understood, had familiarity with, was, like, you talking to bernie sanders, which, by the way, I very much appreciated hearing that, because a lot of people don't give the guy time to talk
# 35:  Yeah
# 36:  To hear him in those sound bites, you don't really get an understanding of who he actually is
# 37:  Right
# 38:  And this is the other thing
# 39:  They're like, well, you can go on all these major network shows, and I did a couple of them
# 40:  I did, like, a morning show
# 41:  I did Brian Williams
# 42:  But broadly, the media, the sort of more corporatized media, as we might say, is exactly what you just described, right
# 43:  They want you to be able to answer in like, 815 seconds or less
# 44:  And when we're talking about big, massive shifts in society, when we're talking about power, when we're talking about technology and how it controls and influences us in the future, you can't have a meaningful conversation within those constraints
# 45:  And so instead, these guys all want to say, repeat these long discredited sort of criticisms
# 46:  And, you know, I'm sure you'll ask the same thing, and that's okay
# 47:  They're fur questions, but it's like, we can't have the conversation if we can't have the space to think and breathe and have this sort of discussion
# 48:  So anyway, they mentioned you
#
# 49:  And I was like, Joe Rogan
# 50:  Joe Rogan
# 51:  Joe Rogan
#
# 52:  Where do I know this name from
# 53:  Before bernie Sanders
# 54:  And I looked back through my Twitter mentions, and the funny thing is, your fans have been harassing me to death for the last years
# 55:  Wonderful people, wonderful people
# 56:  But like go on
# 57:  Jill Rogen Go on, Jill Rogen
# 58:  And I remember after I had just made a Twitter account, neil degrasse Tyson actually helped me get on Twitter, gave me that little initial boost, and they said, Joe Rogan, they linked you
# 59:  And I mouse over your name because I use a desktop, not mobile for this because security reasons
# 60:  And it pops up and I get your avatar, man
# 61:  And I have to say, your logo is the worst thing in the world for people who are trying to be politically serious
# 62:  And they're worried about the national security advisory condemning because, like, this bald guy with this maniacal grin and like, the third eye on his forehead
# 63:  And I'm like, oh, man, that show, that doesn't look good
# 64:  But it's actually like when you watch what you're doing, it's great stuff, man
# 65:  It's great
# 66:  But that first impression, like, this almost didn't happen
# 67:  But everybody who has talked to you, everybody who watches your show, I think they get a very different impression than how you're paying it
# 68:  And for me, it's a wonderful thing because nobody understands that better than I do, right
# 69:  Like, the government ran a smear campaign against me endlessly for six months when I came forward in June of 2013
# 70:  I know we got way off topic here
# 71:  I'll get back to it
# 72:  Fine
# 73:  There's no such thing as off topic
# 74:  We could do talk about whatever great
# 75:  Okay, so for those people, first off, who have no idea who the hell I am, I'm the guy who was behind the revelations of global mass surveillance in 2013
# 76:  I worked for the CIA, I worked for the NSA as a contractor at the NSA, staff officer at the CIA
# 77:  I was undercover working at embassies, and I talked about the difference between this in a book and contractor and government official and how it all sort of lost its meaning
# 78:  But I saw something wrong, and I saw basically the government was violating the law and what I believe to be the constitution of the United States and more broadly, human rights for everyone in the United States and around the world
# 79:  There were domestic surveillance programs
# 80:  There were mass surveillance programs that worked internationally
# 81:  Basically everything that they could monitor, they were monitoring
# 82:  And this is actually like, people go, isn't that obvious
# 83:  Isn't that what they're supposed to do
# 84:  And this is weird, but the answer actually is no
# 85:  Under the framework of our constitution, the government is only supposed to be monitoring people that it has an individualized particularized suspicion of wrongdoing
# 86:  For this is we think about this in the investigative means, right
# 87:  Like all those TV shows where they're like, go and get a warrant
# 88:  The reason they have to do that we fought a revolution over this a couple of hundred years back is the idea that when we had kings, when we had governments of absolute power, they could simply go in your home and go, is this guy a pot smoker
# 89:  Get his diary, whatever it is
# 90:  And just like, if you find evidence of a crime, you march them off to prison, and it's all good
# 91:  You found evidence they're criminal, or you didn't find evidence, well, no harm, no foul
# 92:  You're just doing what government does
# 93:  We were trying to build a better system where it went, yes, the government has extraordinary capabilities, but it only uses them where they're necessary, where they're proportionate to the threat that is presented by this person
# 94:  We shouldn't be afraid of the person who's got, like, a baggie of weed in their dresser or something like that
# 95:  That is not a threat to national security
# 96:  That is not a threat to public safety
# 97:  But what happened in the wake of 911 was a whole bunch of government officials got together behind closed doors
# 98:  And this was actually led, interestingly enough, by the vice president of the United States, cheney
# 99:  Everybody remembers that name, or hopefully I can look that name up
# 100:  Dick cheney and his personal attorney, sort of the giuliani of dick cheney, a guy named David addington and this lawyer, david addington wrote a secret legal interpretation that no one else was allowed to see
# 101:  It was kept in the vice president safe at the white house
# 102:  They weren't giving this even when they told people, and it was just a couple of people in congress
# 103:  Nancy pelosi was one of them
# 104:  And a couple of these other folks, when they talked to the heads of the agency at the NSA and the CIA and the FBI and all this stuff, they told them the white house and the office of legal counsel and the president's attorneys all of these guys had decided this would be legal to do
# 105:  But we can't tell you why
# 106:  We can't show you the legal authorization for it
# 107:  You just got to take our word for it
# 108:  And so they did this
# 109:  And this became a mass surveillance program called Stellar Wind, which they said was supposed to monitor the phone calls and Internet communications, emails and things like that, of everybody in the United States and around the world who they could get access to for links to Al Qaeda
# 110:  Because if you remember, in the wake of the September 11 attacks, they were saying, we thought there could be sleeper cells of Al Qaeda that was just peppered all throughout the country, and they were going to spring up at any moment, of course, like weapons of mass destruction
# 111:  It just didn't exist
# 112:  It was all a power grab
# 113:  But on that basis, they started doing this in secret, and it was completely unconstitutional
# 114:  It was completely illegal, even under the very loose requirements of the Patriot Act
# 115:  But they did it for so long that they got comfortable with it and they thought, this is a really powerful capability
# 116:  What if we started using this for stuff that was other than terrorism
# 117:  Because it wasn't finding any terrorists, because there weren't any terrorists in this context that they were looking for them
# 118:  And the ones who were there were terrorists
# 119:  The program wasn't affected because these were guys in Pakistan that weren't using email and phone calls
# 120:  They were getting on a moped with their cousin who was a courier, who's bringing a letter to his guy who runs the food stand or whatever
# 121:  But bit by bit, over time, this grew and grew and grew, and there were scandals
# 122:  And if you want to drill down on these later, I'll go into them
# 123:  But what happened was, step by step by step, our constitutional rights were changed, and we weren't allowed to know it
# 124:  We were never granted a vote on it
# 125:  And even the many members of Congress, 535 in the United States, they were prohibited from knowing this
#
# 126:  And instead they told only a few select people
# 127:  In the original case, there were only eight members of Congress called the Gang of Eight, who knew about this
# 128:  Then there were the people on the intelligence committees, both in the Senate and the House, who were told about this, but they were only told partially about it
# 129:  They weren't told the full scope of it
# 130:  And now that they have been told about it, because they had security clearances and things like that, they weren't allowed to tell anybody else, even if they objected to it
#
# 131:  And we had one, Senator Ron Wyden, and another one, I believe Tom, Utah was the name of them, who did object to this and who wanted something to happen
# 132:  But because they couldn't tell anybody that was happening, they were sort of doing these weird lassie barks to the press where they were like, we have grave concerns about the way these programs have been carried out, but nobody knew what they were talking about
# 133:  So journalists were like, they've got concerns
# 134:  What is that
# 135:  Lastly
# 136:  What are you trying to say
# 137:  Tiny's been well, but they were getting it wrong
# 138:  They couldn't tell what was happening
# 139:  So what had happened was that we, the American people, had sort of lost our seat at the table of government
# 140:  We were no longer partner to government
# 141:  We had simply become subject to government
# 142:  And I think everybody who's in the world today who is aware of what's going on, whether it's under this administration, the last administration, the one before that, right
# 143:  They have seen a constant kind of shift where we, the public, have less say and less influence over the policy of government
# 144:  With each passing year, there's kind of a new class that's being created, a government class, and then the public civil class that are held to different standards of behavior
# 145:  And when we start talking about leaking and whistleblowing, this becomes even more clear
# 146:  And so what I did was I wanted to clarify that kind of lassie mark
# 147:  I just wanted everybody to know what was going on
# 148:  I didn't want to say, the government can't do this
# 149:  I didn't want to say, this is how you guys have to live
# 150:  Because that's not for me to say
# 151:  But I do believe that everybody in the United States and more broadly
# 152:  People in the world who are having the rights violated by a government should have at least an understanding of how that is happening
# 153:  What the authorities sort of the policies and programs that are enabling
# 154:  That are so that they can protest them
# 155:  So that they can cast a vote about them
# 156:  So that they can say
# 157:  You know what
# 158:  You guys say this is okay, but I disagree
# 159:  This is not okay
# 160:  I object, and I want things to change
# 161:  And so I gathered evidence of what I believe to be criminal or unconstitutional activity on the part of the government
# 162:  And I gave this to journalists right now, I gave this to journalists under a very strict condition here, which was that they published no story in this archive of information simply because it was interesting
# 163:  No clickbait, not anything, just because they thought it would make news, it would get them awards
# 164:  They would only publish stories that they were willing to make an institutional judgment and stand behind
# 165:  And this was three different newspapers that it was in the public interest to know
# 166:  And so then beyond that, there was additional because if you could see sort of what I was doing here, what had happened, what had led us into this pitfall, was that the system of checks and balances that's supposed to self regulate our government had failed
# 167:  The courts had abdicated their role in policing the executive in the Congress because terrorism was such a hot argument at the time
# 168:  They were worried about being criticized and blamed if something went wrong and attack did go through and they didn't have access to the information, that the programs were ineffective
# 169:  So they were just taking the government's word for it, and they didn't want to weigh it in Congress
# 170:  Most of them didn't even know, right
# 171:  And the ones who did know it was the same thing
# 172:  They were getting their pockets stuffed with money by the defense contractors that were getting rich for building these systems, that were violating the rights of each of us
# 173:  So they benefited by just saying nothing
# 174:  And then the executive themselves, whether we're talking about Bush, whether we're talking about Obama, or whether we're talking about Trump now, all these guys were okay with a constantly growing surveillance state because they're the ones whose hands were on the lever at the time
# 175:  They got to aim it
# 176:  They got to use it
# 177:  If you had a little search box in front of you, they would give you the email history and of everybody in the United States, anybody you want
# 178:  If you could pull up their text messages, anybody you want
# 179:  If you could see anything they've ever typed into that Google search box
# 180:  Right
# 181:  Joe, what is the worst thing you've ever typed into that search box that lasts forever
# 182:  And they have a record of that
# 183:  They can get that from Google
# 184:  And so this was the whole thing
# 185:  How do we correct for that
# 186:  So when you have somebody who wants to inform the public of something, and we'll get into the proper channels arguments later, but you can't go through the institution to get these corrected because the institution knows it's wrong and is doing it anyway, right
# 187:  That's the whole origin of the program is they want to do something that they're not allowed to do
# 188:  What do you do
# 189:  I didn't want to say I'm the President of secrets
# 190:  I didn't want to just put this stuff on the Internet, and I could have
# 191:  I'm a technologist, right
# 192:  I worked with the journalists and then to create an adversarial step, someone who would argue against what I believed and hopefully what the journalists believe once they consulted the documents and basically authenticated them
# 193:  Can we get the government to play that role
# 194:  And so before the journalist published any story this is a controversial thing
# 195:  People still criticize me for this, actually
# 196:  They say I was too accommodated in government
# 197:  They could be right
# 198:  Is that the journalist would go to the government and give them a warning, say, we're about to run this story about this secret program that says you did X, Y, and Z
# 199:  Bad thing one, is that right
# 200:  And the government always go, oh, no comment
# 201:  Two, is this going to cause harm
# 202:  Is anybody going to get hurt
# 203:  Is this program effective
# 204:  Is there something we don't understand
# 205:  Is there something Snowden doesn't understand
# 206:  Is this guy just not get it
# 207:  Are these documents fake
# 208:  Whatever you want, say we shouldn't run this story
# 209:  In every case I'm aware of, that process was followed
# 210:  And that's why, because there's a lot of people out there who don't like me, who criticize me, who go, this was unsafe
# 211:  This caused harm to people or whatever
# 212:  We're in 2019 now
# 213:  I came forward and these stories won the Pulitzer Prize for public service journalism starting way back in June of 2013
# 214:  We've had six years to show bodies
# 215:  We've had six years to show harm
# 216:  And you know as well as I do, the government's happy to leak things when it's in their interest
# 217:  Nobody has been hurt as a result of these disclosures because everyone who was involved in them was so careful
# 218:  We wanted to maximize the public benefit while mitigating the potential risks
# 219:  And I think we did a pretty good job
# 220:  But just to get back to the main thing, the original thing that got us off on that trail, when I came forward in June of 2013, I gave one interview to the people who were in the room with the documents
# 221:  Laura Poitrus, glenn Greenwald, ewan Mccainng
#
# 222:  I said who I was
# 223:  I said why I was doing this
# 224:  I said what this was about, why it matters, and that we were constructing a system of turnkey tyranny
#
# 225:  And even if you trust that to Obama, you never know whose hand is going to be on that key next
# 226:  And all they have to do is turn it, and there's nothing we can do to stop it
# 227:  The only thing that's restraining these programs really, is policy, more so than law
# 228:  And the president at any time can sign a napkin, and those policies change
# 229:  Well, after that, I went six months without giving any interviews because I didn't want people to talk about me
# 230:  I wanted them to talk about what actually mattered
# 231:  And the government, of course, was trying very hard to change the conversation, as they always do, to be about who is this guy
# 232:  What have they done
# 233:  What's wrong with them
# 234:  What are their problems
# 235:  Who is this loony guy
# 236:  So they can controversialize the source of a story rather than having to confront the story itself
# 237:  That's why I said, I really kind of appreciate your take on the media and everything like that, because when you don't tell your story, other people will tell it for you
# 238:  They'll say so many things about you, and they'll have these misimpressions like I did because of something as stupid as the avatar that you were using on Twitter, right
# 239:  Where I think it's a certain kind of show with a certain kind of guy, and it's this crazy stuff
# 240:  But when I actually listen to you, when I actually look at the facts, and when I hear you just speak, I go, Actually, this is a thoughtful guy
# 241:  Actually, this is somebody who does care, who does want to look at these things deeply, and appearances and our first impressions can be very misleading
# 242:  I work hard on that
# 243:  I try to mislead people
# 244:  It's good
# 245:  It works to my advantage
# 246:  You're doing a good job, man
# 247:  Thank you
# 248:  I want to bring it back to when you first started with the NSA
# 249:  You started as a contractor, right
# 250:  What was your initial impression, and when did you know that things were really squirrely with the programs
# 251:  So I'm not saying this to put you on the spot
# 252:  I know you've been a busy guy
# 253:  I know you haven't done, I think, shows recently
# 254:  You come back from break
# 255:  Right
#
# 256:  But have you read the book
# 257:  Because it'll just help me, your book, if you haven't got a chance to read it yet
# 258:  No, I have not read your book or got a copy of it
#
# 259:  Okay, well, I will send you a signed copy, brother
# 260:  Beautiful
# 261:  I hope you will read it, and I hope you enjoy it
# 262:  All right
# 263:  So I had a really weird history in the intelligence community
# 264:  I grew up in a federal family in the shadow of Fort Mead
# 265:  Right
# 266:  All these little suburban communities in Maryland where basically the entire industry of the state is the federal government of all these different agencies
# 267:  And then all the subcontractors
# 268:  All the defense industries that serve that government and really are kind of our war making machine
# 269:  Our system of control for the country and the world broadly
# 270:  All that stuff spreads in a couple of hundred mile rays out of DC
# 271:  My mother worked for the district courts rather than the federal courts, and it's kind of funny because she still works there, and those are the courts that are trying to throw me in jail for the rest of my life
# 272:  Now, my father worked for the Coast Guard, retired after 30 years
# 273:  My grandfather was an admiral, and then he worked for the FBI
# 274:  As far back as it goes, my family, my whole line of family, even generations back, was working for the government
# 275:  So it was pretty ordinary, pretty expected for me to go into the same kind of work
# 276:  Now, I started I wasn't super successful in school because I felt and this is the most arrogant thing in the world than anybody says that I had more to learn from computers than I did from biology class
# 277:  And so I spent more and more time focusing on technology than I got mono, and I dropped out of high school, and now it's like, all right, how do I make this up
# 278:  I say drop out of high school, but I'm actually going to community college
# 279:  Right
# 280:  They called it concurrent enrollment, where I'm not taking any classes at high school
# 281:  I'm going to community college instead, and I'm not doing that great there, either
# 282:  It's fine
# 283:  I'm enjoying it
# 284:  But school is school
# 285:  I can't wait to be grown
# 286:  You were bored, and I think a lot of people have felt that, but I ran into somebody at the community college who ran their own home based business doing web design
# 287:  And they could see I was kind of technical, and they went, hey, do you want to work for me
# 288:  And I was like, well, that sounds great
# 289:  And so I started doing web design really early on
# 290:  This is like, gosh, I don't know, probably 1998 vintage during the big boom and then the collapse that followed
# 291:  And the funny thing is, she was married to an NSA analyst, a linguist, right
# 292:  And so she lived on Fort Meade and she ran her business out of their home on Fort Meade
# 293:  That's right up the street from the NSA
# 294:  So before I'm even working there, I'm driving past this building all of the time and trying to figure out what the next step is going to be
# 295:  And I enjoy this
# 296:  It's a good thing for me, and it works well
# 297:  And I start getting trained and certified, all these little industry stamps
# 298:  You've got to get as a technologist to say, oh, you know, this program or whatever, and just start climbing the ladder
# 299:  But then 911 happens, and I'm on Fort Mead when 911 happened
# 300:  I'm just going into work
# 301:  And I tell this in the book in some detail, and I think it's very much worth reading for people who don't know this, because this is forgotten history
# 302:  How old were you at the I was born at 83, so I was probably 18 years old
# 303:  And yeah, I just turned 18 a couple of months before
# 304:  And what people forget is, who knew what was going on before anybody else on September 11
# 305:  The intelligence community
# 306:  And what did they do
# 307:  Did they give out a public warning
# 308:  Did they tell you guys to evacuate
# 309:  Did they say, do this
# 310:  No, not for everybody
# 311:  Not for a long time
# 312:  But at the NSA, then Director Michael Hayden, he was a general, he later became director of the CIA, ordered the entire campus evacuated of thousands, tens of thousands of people, actually, and just said, Go home
# 313:  Right
# 314:  The CIA did the same thing
# 315:  They were running on skeleton crews at the moment
# 316:  The country needed them more than they ever had
# 317:  And I get a call, and I hear a call that's from my boss's wife, her husband to her, he's calling from the NSA
# 318:  He's saying, hey, I think Ed should leave for the day because I'm the only employee of this business besides her, because I think they're going to close the base down
# 319:  I'm like, this is crazy
# 320:  It never closes down
# 321:  We don't know what's happening
# 322:  Then we start checking the news, which is through websites, right
# 323:  Because we're doing all this stuff, and suddenly it's the big story everywhere, and nobody understands how big it is yet
# 324:  Most of us are like, oh, it's going to mess with our workday
# 325:  Oh, it's going to mess with our commute
# 326:  But when I'm leaving, I hear car horns all over the base
# 327:  It's the craziest thing because this is a military base, right
# 328:  It's right outside the NSA
# 329:  And I entered just this absolute state of pandemonium as I go past Canine Road, which is the road that travels right in front of the NSA's headquarters
# 330:  And it's just a parking lot as far as you can see
# 331:  They have military police out under the stoplights directing traffic because this mass evacuation and I still have no idea what's happening
# 332:  Like, the story is still developing, but I will never forget that image
# 333:  Why did these people have so much power and so much money and so much authority that if at the moment we need them the most, they're the first ones in the country that are leaving their buildings
# 334:  And later on they said and this is covered in a book, I believe
# 335:  I think it's James Bamford who interviewed that director of NSA who gave that order about what was happening
# 336:  He was going, well, he called his wife and he was asking where their kids were and everything like that
# 337:  And then after that, he wanted to think about, well, where could these other planes that they knew were in the air, that it hadn't struck yet
# 338:  Where could they be headed
# 339:  And this sort of shows how self centric the intelligence community is
# 340:  This is the DC
# 341:  Metro area, right
# 342:  They could hit the White House, they could hit Congress, they could hit the Supreme Court
# 343:  And they go, oh, they're going to fly their planes into the CIA headquarters
# 344:  They're going to fly their planes into the NSA headquarters
# 345:  And of course, it was never realistic that these would be the targets, but on that basis, they were like, let's get our bacon out of the pan
#
# 346:  I don't say this, I'm sorry, but just in the interest of, wasn't it possible that they could have attacked those places
# 347:  I mean, they attacked the Pentagon
# 348:  They knew that there was a look, it's absolutely possible they could have attacked your Denny's, right
#
# 349:  But it's a question of risk assessment
# 350:  If you have planes in the air
# 351:  If you believe there's an ongoing terrorist attack that's happening in the United States right now
# 352:  And if you have built history's greatest surveillance agencies
# 353:  Right
# 354:  The most powerful intelligence forces in the history of the species
# 355:  You are going to take those off the board
# 356:  Or at least the majority of their personnel off the board
# 357:  Then in a chance that you have no sort of grounds for substantiating
# 358:  That they could be targeting you to begin with simply because they could well
# 359:  Somebody else will get hit with those
# 360:  As you say, it's going to be the Pentagon, right
# 361:  It's going to be the World Trade Center
# 362:  It's going to be someone somewhere
# 363:  And the more minutes you're in front of that desk, the higher the chances, even if it's a very small
# 364:  Chance
# 365:  Even if it's somebody who doesn't work on terrorism, right
# 366:  Maybe if it's somebody who normally works finance in North Korea, right, but they go, look, this is an emergency
# 367:  Everybody understands
# 368:  You don't need to explain this
# 369:  You just go, stop what you're doing
# 370:  Look at financial transactions related to who purchased these plane tickets
# 371:  Do this
# 372:  You just go full spectrum and go, anything you can do right now, if the building gets hit, we get hit
# 373:  That's what we signed up for
# 374:  Nobody wants that, right
# 375:  That's not the desired outcome
# 376:  But if they had asked the staff to do that, they all would have agreed
# 377:  That's what these people signed up to do
# 378:  And yet the director goes, no, we're just no, we're not going to take that risk
# 379:  I think it says so much about the bureaucratic character of how government works, the people who rise to the top of these governments
# 380:  It's about risk management for them
# 381:  It's about never being criticized for something
# 382:  And if we want to get really controversial and this is something that will haunt me, because people will bring it up again and again and again
# 383:  People ask about people still criticize me in the book
# 384:  I talk about aliens and Chemtrails and things like that
# 385:  In fact, there's no evidence for that
# 386:  I went looking on the network, right, and I know, Joe, I know you want there to be aliens
# 387:  I do
# 388:  I know Neil degrasse Tyson badly wants there to be aliens, and there probably are, right
# 389:  But the idea that we're hiding them, if we are hiding them I had ridiculous access to the networks of the NSA, the CIA, the military, all these groups
# 390:  I couldn't find anything, right
# 391:  So if it's hidden and it could be hidden, it's hidden really damn well, even from people who are on the inside
# 392:  But the main thing is conspiracy theories, right
# 393:  Everybody wants to believe in conspiracy theories because it helps life make sense
# 394:  It helps us believe that somebody is in control, that somebody is calling the shots, that these things all happened for a reason, this, that, and the other
# 395:  There are real conspiracies, but they're not typically they've got tens of thousands of people working on them
# 396:  Unless you're talking about the existence of the intelligence community itself, which is basically constructed on the idea that you can get I think there are 4 million or 1
# 397: 4 million people in the United States who hold security clearances, and you can get all of these people to not talk ever to journalists, this, that, or the other
# 398:  But when you look back at the 911 report and when you look back at the history of what actually happened, what we can prove, right
# 399:  Not what we can speculate on, but what are the least commonly agreed facts, it's very clear to me as someone who worked in the intelligence community, not during this period, of course
# 400:  I was too young, but very shortly thereafter that these attacks could have been prevented
# 401:  And in fact, the government says this too, but the government goes, the reason that these attacks happen, the reason that they weren't prevented, is what they call stove piping, right
# 402:  There was not enough sharing they needed to break down the walls
# 403:  And the restrictions that were chaining these poor patriots at the NSA and the CIA and the FBI from all working on the same team
# 404:  And to some extent, they're correct on this, right
# 405:  There were limits on the way agencies were supposed to play ball with each other
# 406:  But I worked there, and I know how much of this is bullshit and how much is this is not
# 407:  Those are procedural and policy limits, in some cases, legal limits on what can be shared without following the process, without doing this, that, or the other, without basically asking for permission, without getting a sign off or anything like that
# 408:  If the FBI wanted to send absolutely everything they had to the CIA, they could have done so
# 409:  If the CIA wanted to send everything they had to the FBI, they could have done so
# 410:  They didn't, and people died as a result
# 411:  Now, government goes, bureaucratic, procedural realism was responsible, and it's because we had too many restrictions on the intelligence community
# 412:  And this is what led to the world post 911, where all of our rights sort of evaporated, where they went, well, restrictions on what these agencies can do are costing lives
# 413:  Therefore, naturally, we just have to unchain these guys, and everything will be better, right
# 414:  And if you remember that post 911 moment, you can understand how that actually could come off as persuasive, how that might be a kind of thing to go
# 415:  You go, all right, well, that makes sense because everybody was terrified
# 416:  There were people quite quickly who got their heads back on their shoulders the right way
# 417:  There were some of them who never lost their heads at all and who protested the Iraq war
# 418:  At the same time, my daughter himself was signing up to go fight it, volunteering for the army
# 419:  And we'll get into that in a minute
# 420:  But everything that has followed in the decades past came from the fact that in a moment of fear, we lost our heads, and we abandoned all the traditional constitutional restraints that we put on these agencies, and we abandon all of the traditional political restraints and just social constraints, ideological systems of belief about the limitations that the secret police should have in a free and open society
# 421:  And we went, look, terrorists
# 422:  We created shows like 24 and Jack Bauer where he's threatening knife people's eyeballs out if they won't tell him this, that, or the other
# 423:  And we entered this era of increasingly unlimited government as a result
# 424:  Now, in hindsight, we go, we shouldn't have been surprised, but at the time, everyone panicked, right
# 425:  But if you go back to did that help
# 426:  And we know the answer now is in fact
# 427:  No, it did not
# 428:  It made things worse
# 429:  I don't think any historian is going to look at the Bush administration and go, this improved the position of the United States and the world
# 430:  But if you go back, wind back the tape to that pre 911 moment, wind back the tape to those silos and those walls that they said needed to come down because that was restraining government instead of the rules that said, well, you can share these things, but there's got to be basis, there's got to be a justification
# 431:  You've got to go, why are we trading people's information like baseball cards and all of this stuff
# 432:  It's super easy as an intelligence officer to justify sharing information about a suspected terrorist who you think is planning to kill people or is even just in a country they shouldn't be or a place they shouldn't be or doing something you don't think they should be with another agency because no one's going to question that
# 433:  A judge isn't going to question that
# 434:  Any judge in the world will stamp that warrant without even thinking about it and then go to bed that night without a care in the world
# 435:  Because you're not spying on a journalist
# 436:  You're not spying on a human rights defender, right
# 437:  This is not an edge case
# 438:  This is someone that you believe to be associated with al Qaeda or whatever
# 439:  Now, this is all a lot of preamble to say that essential fact
# 440:  Government agrees, everyone agrees
#
# 441:  The tax probably could have been prevented if information had been shared
# 442:  So why wasn't the information shared
# 443:  Government says information wasn't shared because of these restrictions, and it's half true because every important lie has some criminal truth to it
# 444:  There were these barriers, but the reality is, why were those barriers respected
# 445:  In the case of a major terrorist plot, why wasn't the CIA sharing information with the FBI
# 446:  Why wasn't the FBI sharing information with the NSA
# 447:  Why was the NSA sharing information with the CIA in the case of a major terrorist plot
#
# 448:  And if you've worked in government, if you've worked in the intelligence community, if you work in any large institution, if you work at a company that sells batteries, you know that every office is fighting the other office for budget, for cloud, for promotions
# 449:  And this is the sad reality of what actually happened
# 450:  Every one of those agencies wanted to be the guy who busted the plot
# 451:  They wanted to be the one who got credit for it
# 452:  And they didn't realize how serious it was until it was too late because they were competing with each other rather than cooperating
# 453:  That's exactly what I was going to ask you if that was the issue, the competition between these agencies, because they are very proud of the CIA accomplishing something or the FBI accomplishing something, and they want to be the one to take credit for that
# 454:  Yeah
# 455:  And, I mean, I think it's important, like, in their defense, because nobody else here is going to provide a defense for them
# 456:  Is that that's actually darkly human
# 457:  Again, this happens in every industry
# 458:  This happens in every sort of big corporate thing, because you want to get promoted
# 459:  And everybody's putting in their achievements at the end of the year for what they did
# 460:  If you're the guy who does that, you're going straight to the top
# 461:  But their solution so we have a weird delay here for folks that are listening, right
# 462:  So their solution, instead of having someone be responsible for bridging the gap and providing that information to each individual agency, their solution was mass surveillance
# 463:  Oh, no, they're different things
# 464:  911 is what woke these guys up, right, basically
# 465:  And they went, well, we screwed up, and Americans died as a result
# 466:  We really don't want to take the hit on that
# 467:  And to be honest, the government had no interest in putting the hit on them
# 468:  To be honest
# 469:  The public had no interest in putting the hit on them at the time, because everybody understood terrorism is a real thing
# 470:  There are bad people in the world
#
# 471:  And that's true, right
# 472:  That will always be true
# 473:  There's always going to be criminals
# 474:  There's always going to be terrorists, whether they're at your church, whether they're across the ocean
#
# 475:  There are people out there who are angry, they're disenfranchised, they're violent, and they just want to harm something
# 476:  They want to change something, even in a negative way, because that's what they feel is all they have left, which these are criminals, right
# 477:  These are people that we don't need to pity, but if we ever want to stop it, we do need to understand it, and where those things come from, where those drives come from in the first place
# 478:  Basically, everybody went, all right, how do we stop this
# 479:  Because nobody wants to feel unsafe
# 480:  Nobody wants to feel like the building is going to come down the next time you go in it
# 481:  And so everybody just went, I don't care who does it, stop it
#
# 482:  And they said this to Dick Cheney, which is a historic mistake
# 483:  Dick Cheney knows how government works
# 484:  He was the person in that White House who was best placed to know all the levers of government, all the interagency cooperation, where we were strong, where we were weak, what we could do, what we were not allowed to do
# 485:  And what he did was he took that little dial on what we're not allowed to do, and he changed it all the way until it broke and snapped off
# 486:  And then there was nothing that we couldn't do anymore
# 487:  And you were there while this was happening
# 488:  No, I was not
# 489:  Again, this is 2001
# 490:  I was 18 years old
# 491:  I was working on the base
# 492:  I drove past the building, but that was it
# 493:  This is all hindsight
# 494:  This is biography
# 495:  This is documented history
# 496:  But this is not the gospel of Edward Snowden
# 497:  I don't know this, right
# 498:  This is public record
# 499:  This is what we all know what we have, though the reason that I bring this up is this is a teachable moment, because there's so many people right now in the Trump administration who go, look, this guy has too much power
# 500:  He's abusing it against immigrants, he's abusing it against domestic opponents, he's doing whatever
# 501:  He's trying to hurt political rivals in the next election, all of this stuff
# 502:  And we can get into this stuff later if you want, in detail
# 503:  But the bottom line is they're going, this is a guy who's in the White House who's thrown elbows, he wants to hurt people
# 504:  As long as he can convince the Americans that those are the bad guys, right
# 505:  That's the enemy doesn't matter if they're far away, it doesn't matter if they're close at home
# 506:  Whoever he's against, he's going to harm
# 507:  And the dark thing is, this is actually why he was elected
# 508:  In moments of fear, where the world starts falling apart and this happens in authoritarian country after country
# 509:  This is why you have Vladimir Putin in Russia, who's been there for 20 years, right
# 510:  President for basically 20 years
# 511:  Think about that
# 512:  He sort of skipped in the middle there because he had to dodge the fact that presidents can only serve so many consecutive terms
# 513:  So he dropped down prime minister and they came back as president
# 514:  But think about that
# 515:  How do you get that kind of political longevity
# 516:  And it's because if you know anything about Russian history, which even I don't know that much about it, the 90s after the collapse of the Soviet Union were an extraordinarily dark time
# 517:  If you look at Russian cinema, all they had were gangster movies, right
# 518:  All they had was the disintegration of society, how things are dark and broken
# 519:  No one trusts each other
# 520:  Pensions were no longer being paid, Social Security is not there anymore
# 521:  Like, there's nothing to buy, there's nothing to do, there's no job, no one had a future
# 522:  And so they went, if there's somebody who can lead us out of this, if there's somebody who will fix this, who will find us an enemy and defeat that enemy to restore prosperity, we'll put them in office
#
# 523:  We see it happen in Turkey with Erdogan, right
# 524:  We've seen it happen successively with bad governments, even in Western democracies
# 525:  We see it happening, sadly, in places like Poland and Hungary
# 526:  You can even argue it's happening in the United Kingdom, right
#
# 527:  And now there are a lot of people arguing, that's exactly what we're seeing with Donald Trump's White House in the United States
# 528:  And this is the lesson that we didn't learn from 2001, is when we become fearful, we become vulnerable, right
# 529:  To anyone who promises they will make things better, even if they have no ability to make things better, even if they will actively make things worse, even if they will make things better for themselves and their buddies by taking from you
# 530:  But if they tell you that they'll make things better and you believe them in a moment of fear, that typically leads to unfortunate outcomes
# 531:  So sorry, let me turn this back over to you because we got way off track there
# 532:  No, that's all right
# 533:  I want to bring it back to the initial question
# 534:  So you're working for the NSA
# 535:  When do you realize there's a huge issue, and when do you feel this responsibility to let the american people know about this issue
# 536:  When do you contact these journalists
# 537:  And what was the thought process regarding this
# 538:  What steps did you go through once you realize that this was in violation of the constitution, and that even with the laws of the patriot act and the patriot act, too, things had changed so radically that you knew this was wrong and you had to do something about it, you felt a responsibility to speak out
# 539:  Okay, so since we gave so much historical preamble, let me just give the cliff notes version to get us up to that
# 540:  So after september 11, I'm a little bit lost
# 541:  I'm doing my technical stuff, but it doesn't really feel like it matters anymore
# 542:  Like, I'm making more money, I'm becoming more accomplished, but the world is on fire, right
# 543:  You remember there was a crazy mood of patriotism in the country because we were all trying to come together to get through it
# 544:  You remember, like, people were sticking dixie cups on the top of every chain link fence, on every overpass
# 545:  It was like, stand together
# 546:  Never forget united we stand flags on every car
# 547:  Exactly
# 548:  And I was a young guy who is not especially political, and I come from military background, federal, family, all that stuff
# 549:  And so that means I'm very vulnerable to this kind of stuff
# 550:  I see it on the news, and bush and all his sort of cronies are going, look, it's al qaeda
# 551:  It's a terrorist organization
# 552:  They have all these international connections
# 553:  There's iraq, dictators, weapons of mass destruction
# 554:  They're holding the world at ransom
# 555:  You got colin powell at the UN
# 556:  Dangling little vials of, like, fake anthrax
# 557:  I felt an obligation to do my part, and so I volunteered to join the army
# 558:  You probably can't tell from looking at me, but I'm not going to be at the top of the MMA circuit anytime soon
# 559:  So it didn't work out
# 560:  I joined a special program that was called the 18 x ray program, where they take you in off the street, and they actually give you a shot at becoming a special forces soldier
# 561:  So you train harder, and special platoons, you go further
# 562:  And I ended up breaking my legs, basically
# 563:  So they put me out on discharge
# 564:  Yeah, it was basically what it was
# 565:  They were shin splints that I was too dumb to get off of, right
# 566:  So I kept marching underweight, and I'm a pretty light guy to begin with
# 567:  I had a 24 inch waist when I joined the army
# 568:  Girls are jealous
# 569:  I think I weighed, like, £128
# 570:  I was in great shape in boot camp because I came up really quick, because all I could do was gain, but it was just too much on my frame because I wasn't that active
# ...
# 1701:  And the mitigation that you're trying to do is what would be the loss, what would be the damage done to you if this stuff was exploited
# 1702:  Much more realistic than worrying about these things that I call voodoo hacks, right, which are like next level stuff and actually just a shout out for those of your readers who are interested in this stuff
# 1703:  I wrote a paper on this specific problem
# 1704:  How do you know when a phone is actually off
# 1705:  How do you know when it's actually not
# 1706:  Spying on you with a brilliant, brilliant guy
# 1707:  Named Andrew Bunny Huang
# 1708:  He's an MIT PhD in, I think, electrical engineering called the introspection engine that was published in the journal of open engineering
# 1709:  You can find it online, and it will go as deep down in the weeds, I promise you, as you want
# 1710:  We take an iPhone six
# 1711:  This was back when it was fairly new, and we modified it so we could actually not trust the device to report its own state, but physically monitor its state to see if it was spying on you
# 1712:  But for average people, right, this academic, that's not your primary threat
# 1713:  Your primary threats are these bulk collection programs
# 1714:  Your primary threat is the fact that your phone is constantly squawking to these cell phone towers
# 1715:  It's doing all of these things because we leave our phones in a state that is constantly on you're constantly connected, right
# 1716:  Airplane mode doesn't even turn off WiFi, really anymore
# 1717:  It just turns off the cellular modem
# 1718:  But the whole idea is we need to identify the problem
# 1719:  And the central problem with smartphone use today is you have no idea what the hell it's doing at any given time
# 1720:  Like, the phone has the screen off, you don't know what it's connected to, you don't know how frequently it's doing it
#
# 1721:  Apple and iOS, unfortunately, makes it impossible to see what kind of network connections are constantly made on the device and to intermediate them going, I don't want Facebook to be able to talk right now
# 1722:  I don't want google to be able to talk right now
# 1723:  I just want my secure messenger app to be able to talk
# 1724:  I just want my weather app to be able to talk
# 1725:  But I just checked my weather, and now I'm done with it
# 1726:  So I don't want that to be able to talk anymore
# 1727:  And we need to be able to make these intelligent decisions on not just an app by app basis, but a connection by connection basis, right
# 1728:  Let's say you use Facebook because for whatever judgment we have, a lot of people might do it
# 1729:  You want it to be able to connect to Facebook's content servers
# 1730:  You want to be able to message a friend
# 1731:  You want to be able to download a photograph or whatever, but you don't want it to be able to talk to an ad server
#
# 1732:  You don't want it to talk to an analytics server that's monitoring your behavior, right
# 1733:  You don't want to talk to all these third party things because facebook crammed their garbage into almost every app that you download, and you don't even know what's happening because you can't see it
# 1734:  Right
# 1735:  And this is the problem with the data collection used today, is there is an industry that is built on keeping this invisible
# 1736:  And what we need to do is we need to make the activities of our devices, whether it's a phone, whether it's computer, or whatever, more visible and understandable to the average person and then give them control over it
# 1737:  If you could see your phone right now, and at the very center of it is a little green icon that's your handset, or it's a picture of your face, whatever, and then you see all these little spokes coming off of it
# 1738:  That's every app that your phone is talking to right now, or every app that is active on your phone right now and all of the hosts that it's connecting to
# 1739:  And you can see right now, once every 3 seconds your phone is checking into Facebook and you could just poke that app and then boom
# 1740:  It's not talking to Facebook anymore
# 1741:  Facebook is not allowed
# 1742:  Facebook speaking privileges have been revoked
# 1743:  Right
# 1744:  You would do that
# 1745:  We would all do that
#
# 1746:  If there was a button on your phone that said do what I want but not spy on me, you would press that button, right
# 1747:  That button does not exist right now
# 1748:  And both Google and Apple, unfortunately Apple is a lot better at this than Google, but neither of them allow that button to exist
#
# 1749:  In fact, they actively interfere with it because they say it's a security risk
# 1750:  And from a particular perspective, they actually aren't wrong there
# 1751:  But it's not enough to go, we have to lock that capability off from people because we don't trust they would make the right decisions
# 1752:  We think it's too complicated for people to do this
# 1753:  We think there's too many connections being made
# 1754:  Well, that is actually a confession of the problem right there
# 1755:  If you think people can't understand it, if you think there are too many communications happening, if you think there's too much complexity in there, it needs to be simplified
# 1756:  Just like the President can't control everything like that
# 1757:  If you have to be the President of the phone, and the phone is as complex as the United States government, we have a problem guys
# 1758:  This should be a much more simple process
# 1759:  It should be obvious
# 1760:  And the fact that it's not, and the fact that we read story after story, year after year saying all your data has been breached here, this company is spying on you here, this company is manipulating your purchases or your search results, or they're hiding these things from your timeline, or they're influencing you or manipulating you in all of these different ways
# 1761:  That happens as a result of a single problem
# 1762:  And that problem is inequality of available information
#
# 1763:  They can see everything about you, they can see everything about what your device is doing and they can do whatever they want with your device
# 1764:  You on the other hand, owned the device
# 1765:  Well, rather you paid for the device
#
# 1766:  But increasingly these corporations own it
# 1767:  Increasingly these governments own it
# 1768:  And increasingly we are living in a world where we do all the work right, we pay all the taxes, we pay all the costs, but we own less and less and nobody understands this better than the youngest generation
# 1769:  Well, it seems like our data became a commodity before we understood what it was
# 1770:  It became this thing that's insanely valuable to Google and Facebook and all these social media platforms
# 1771:  Before we understood what we were giving up, they were making billions of dollars
# 1772:  And then once that money is being earned, and once everyone's accustomed to the situation, it's very difficult to pull the reins back
# 1773:  It's very difficult to turn that course around precisely because the money then becomes power, right
# 1774:  The information then becomes influence
# 1775:  That also seems to be the same sort of situation that would happen with these mass surveillance states
# 1776:  Once they have the access, it's going to be incredibly difficult for them to relinquish that
# 1777:  Right, yeah
# 1778:  No, you're exactly correct
# 1779:  And this is the subject of the book
# 1780:  This is the permanent record, and this is where it came from
# 1781:  This is how it came to exist
# 1782:  The story of our lifetimes is how intentionally, by design, a number of institutions, both governmental and corporate, realized it was in their mutual interest to conceal their data collection activities, to increase the breadth and depth of their sensor networks that were sort of spread out through society
# 1783:  Remember back in the day, intelligence collection in the United States, even at Sigma, used to mean sending an FBI agent to put alligator clips on an embassy building or sending in somebody disguised as a workman and they put a bug in a building
# 1784:  Or they built a satellite listening site, right
# 1785:  We call these foreign sat or foreign satellite collection
# 1786:  We're out in the desert somewhere
# 1787:  They built a big parabolic collector, and it's just listening to satellite emissions, right
# 1788:  But these satellite emissions, these satellite links were owned by militaries
# 1789:  They were exclusive to governments, right
# 1790:  It wasn't affecting everybody broadly
# 1791:  All surveillance was targeted because it had to be
# 1792:  What changed with technology is that surveillance could now become indiscriminate
# 1793:  It could become dragnet, it could become bulk collection, which should become one of the dirtiest phrases in the language, if we have any kind of decency
# 1794:  But we were intentionally this was intentionally concealed from us, right
# 1795:  The government did it
# 1796:  They used classification, companies did it
# 1797:  They intentionally didn't talk about it
# 1798:  They denied these things were going, they said, you agreed to this and you didn't agree to nothing like this, I'm sorry, right
# 1799:  They go, we put that terms of service page up, and you click that
# 1800:  You clicked a button that said, I agree, because you were trying to open an account so you could talk to your friends
# 1801:  You were trying to get driving directions, you were trying to get an email account
# 1802:  You weren't trying to agree to some 600 page legal form
# 1803:  Even if you read, you wouldn't understand
# 1804:  And it doesn't matter even if you did understand, because one of the very first paragraphs and it said, this agreement can be changed at any time unilaterally without your consent by the company, right
# 1805:  They have built a legal paradigm that presumes records collected about us do not belong to us
# 1806:  This is sort of one of the core principles on which mass surveillance, from the government's perspective in the United States is legal
# 1807:  And you have to understand that all the stuff we talked about today, the government says everything they do is legal, right
# 1808:  And they go, so it's fine
# 1809:  Our perspective as the public should be, well, that's actually the problem, because this isn't, okay
#
# 1810:  The scandal isn't how they're breaking the law
# 1811:  The scandal is that they don't have to break the law
# 1812:  And the way they say they're not breaking the law is something called the third party doctrine
#
# 1813:  A third party doctrine is a legal principle derived from a case in, I believe, the 1970s called Smith versus Maryland
# 1814:  And Smith was this knucklehead who was harassing this lady, making phone calls to her house
# 1815:  And when she would pick up, he just, I don't know, sit there, heavy breathing, whatever, like a classic creeper
# 1816:  And it's terrifying, this poor lady
# 1817:  So she calls the cops and says, one day I got one of these phone calls, and then I see this car creeping past my house on the street, and she got a license plate number
# 1818:  So she goes to the cops, and she goes, Is this the guy
# 1819:  And the cops again, they're trying to do a good thing here
# 1820:  They look up his license plate number, and they find out where this guy is, and then they go, well, what phone number is registered to the house
# 1821:  And they go to the phone company, and they say, can you give us this record
# 1822:  And the phone company says, yeah, sure, and it's the guy
# 1823:  The cops got their man, right
# 1824:  So they go arrest this guy, and then in court, his lawyer brings all this stuff up, and they go, you did this without a warrant
# 1825:  So that was the problem, was they went to the phone company and they got the records without a warrant
# 1826:  They just asked for it, or they subpoenaed it, some lower standard of legal review, and the company gave it to him and got the guy
# 1827:  They marched him off to jail, and they could have gotten a warrant, right
# 1828:  But it was just expedient
# 1829:  They just didn't want to take the time
# 1830:  The small town cops, you can understand how it happens
# 1831:  They know the guy's a creeper
# 1832:  They just want to get them off to jail
# 1833:  And so they made a mistake
# 1834:  The government doesn't want to let it go
#
# 1835:  They fight on this, and they go, they weren't his records
# 1836:  And so because they didn't belong to him, he didn't have a Fourth Amendment right to demand a warrant be issued for them
# 1837:  They were the company's records, and the company provided them voluntarily, and hence, no warrant was required because you can get whatever you want without a warrant as long as it's yours
# 1838:  Now, here's the problem
# 1839:  The government extrapolated a principle in a single case of a single known, suspected criminal who they had real good reasons to suspect was their guy, and use that to go to a company and get records from them and establish a precedent
# 1840:  These records don't belong to the guy, they belong to the company
# 1841:  And then they said, well, if one person doesn't have a Fourth Amendment interest in records held by a company, no one does
# 1842:  And so the company then has absolute proprietary ownership of all of these records about all of our lives
#
# 1843:  And remember, this is back in the 1970s
# 1844:  The Internet hardly exists in these kind of contexts
# 1845:  Smartphones don't exist
# 1846:  Modern society, modern communications don't exist
# 1847:  This is the very beginning of the technological era
# 1848:  And flash forward now 40 years, and they are still relying on this precedent about this one pervy creeper to go
# 1849:  Nobody has a privacy right for anything that's held by a company
# 1850:  And so long as they do that, companies are going to be extraordinarily powerful and they're going to be extraordinarily abusive
# 1851:  And this is something that people don't get
#
# 1852:  They go, oh, well, it's data collection, right
# 1853:  They're exploiting data
# 1854:  This is data about human lives
# 1855:  It is data about people
# 1856:  These records are about you
# 1857:  It's not data that's being exploited
# 1858:  It's people that are being exploited
# 1859:  It's not data that's being manipulated
#
# 1860:  It's you that's being manipulated
# 1861:  And this is something that I think a lot of people are beginning to understand
# 1862:  The problem is the companies and the governments are still pretending they don't understand or disagreeing with this
# 1863:  And this reminds me of something that one of my old friends, john Perry Barlow, who served with me at the Freedom of the Press Foundation I'm the president of the board, used to say to me, which is, you can't awaken someone who's pretending to be asleep
# 1864:  He said it's an old Native American thing
# 1865:  That's a great expression
# 1866:  I think that's a good way to end this
# 1867:  Ed, thank you very much for doing this
# 1868:  I really appreciate it
# 1869:  Please tell everybody the title of your book, and it's available right now
# 1870:  Sure
# 1871:  Yes, it is
# 1872:  It's on shelves everywhere, at least until the government finds some other way to ban it
# 1873:  It is called Permanent Record, and I hope you will read it
# 1874:  I will read it, and I think what you've done is incredibly brave, and I think you're a very important part of history
# 1875:  I think when all is said and done, what you did and what you exposed is going to change the way we view mass surveillance, change the way we view government oversight, and change the way we view the distribution of information
# 1876:  I really think it's very important, and it was an honor to talk to you, man
# 1877:  Thank you
# 1878:  It was my pleasure
# 1879:  Thank you so much for having me take care of yourself, man
#
# 1880:  Stay safe
# 1881:  No, don't stay safe
# 1882:  Stay safe
#
# 1883:  Open
# 1884:  Stay free
# 1885:  Open the possibility
# 1886:  Take care
# 1887:  Bye
# 1888:  Take care
# 1889:
