# %%
# !pip install ruptures
# Out:
# Collecting ruptures
#   Downloading ruptures-1.1.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 3.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy in /home/poloniki/.pyenv/versions/3.8.12/envs/quint/lib/python3.8/site-packages (from ruptures) (1.21.0)
# Requirement already satisfied: scipy in /home/poloniki/.pyenv/versions/3.8.12/envs/quint/lib/python3.8/site-packages (from ruptures) (1.9.1)
# Installing collected packages: ruptures
# Successfully installed ruptures-1.1.7

# %%
from pathlib import Path

import nltk
import numpy as np
import ruptures as rpt  # our package
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import regexp_tokenize
from ruptures.base import BaseCost
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.colors import LogNorm# Start writing code here...

# %%
nltk.download("stopwords")
STOPWORD_SET = set(
    stopwords.words("english")
)  # set of stopwords of the English language
PUNCTUATION_SET = set("!\"#$%&'()*+,-./:;<=>?@[\\]^_`{|}~")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def preprocess(list_of_sentences: list) -> list:
    """Preprocess each sentence (remove punctuation, stopwords, then stemming.)"""
    transformed = list()
    for sentence in list_of_sentences:
        ps = PorterStemmer()
        list_of_words = regexp_tokenize(text=sentence.lower(), pattern="\w+")
        list_of_words = [
            ps.stem(word) for word in list_of_words if word not in STOPWORD_SET
        ]
        transformed.append(" ".join(list_of_words))
    return transformed

# %%
def draw_square_on_ax(start, end, ax, linewidth=0.8):
    """Draw a square on the given ax object."""
    ax.vlines(
        x=[start - 0.5, end - 0.5],
        ymin=start - 0.5,
        ymax=end - 0.5,
        linewidth=linewidth,
    )
    ax.hlines(
        y=[start - 0.5, end - 0.5],
        xmin=start - 0.5,
        xmax=end - 0.5,
        linewidth=linewidth,
    )
    return ax

# %%
with open('../quint/data/sample_texts/joe_rogan_tr.txt') as f:
    doc = f.readlines()
doc = doc[0].replace("?", ".")
sentences = doc.split('.')
original_text = sentences.split(". ")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/poloniki/code/poloniki/quint/notebooks/Change point detection.ipynb Cell 6 in <cell line: 3>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/poloniki/code/poloniki/quint/notebooks/Change%20point%20detection.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # Loading the text
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/poloniki/code/poloniki/quint/notebooks/Change%20point%20detection.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> filepath = Path("../quint/data/sample_texts/joe_rogan_tr.txt'")
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/poloniki/code/poloniki/quint/notebooks/Change%20point%20detection.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> original_text = filepath.read_text().split(". ")
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/pathlib.py:1236, in Path.read_text(self, encoding, errors)
#    1232 def read_text(self, encoding=None, errors=None):
#    1233     """
#    1234     Open the file in text mode, read it, and close the file.
#    1235     """
# -> 1236     with self.open(mode='r', encoding=encoding, errors=errors) as f:
#    1237         return f.read()
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/pathlib.py:1222, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1220 if self._closed:
#    1221     self._raise_closed()
# -> 1222 return io.open(self, mode, buffering, encoding, errors, newline,
#    1223                opener=self._opener)
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/pathlib.py:1078, in Path._opener(self, name, flags, mode)
#    1076 def _opener(self, name, flags, mode=0o666):
#    1077     # A stub for the opener argument to built-in open()
# -> 1078     return self._accessor.open(self, flags, mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: "../quint/data/sample_texts/joe_rogan_tr.txt'"

# %%
# transform text
transformed_text = preprocess(original_text)
# print original and transformed
ind = 3
print("Original sentence:")
print(f"\t{original_text[ind]}")
print()
print("Transformed:")
print(f"\t{transformed_text[ind]}")
# Out:
# Original sentence:
# 	They're taking money from the russians
#
# Transformed:
# 	take money russian

# %%
# Once the text is preprocessed, each sentence is transformed into a vector of word counts.
vectorizer = CountVectorizer(analyzer="word")
vectorized_text = vectorizer.fit_transform(transformed_text)

msg = f"There are {len(vectorizer.get_feature_names())} different words in the corpus, e.g. {vectorizer.get_feature_names()[20:30]}."
print(msg)
# Out:
# There are 2203 different words in the corpus, e.g. ['2012', '2013', '2016', '2019', '20th', '230', '24', '260', '2776', '30'].
# /shared-libs/python3.9/py/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
class CosineCost(BaseCost):
    """Cost derived from the cosine similarity."""

    # The 2 following attributes must be specified for compatibility.
    model = "custom_cosine"
    min_size = 2

    def fit(self, signal):
        """Set the internal parameter."""
        self.signal = signal
        self.gram = cosine_similarity(signal, dense_output=False)
        return self

    def error(self, start, end) -> float:
        """Return the approximation cost on the segment [start:end].

        Args:
            start (int): start of the segment
            end (int): end of the segment
        Returns:
            segment cost
        Raises:
            NotEnoughPoints: when the segment is too short (less than `min_size` samples).
        """
        if end - start < self.min_size:
            raise NotEnoughPoints
        sub_gram = self.gram[start:end, start:end]
        val = sub_gram.diagonal().sum()
        val -= sub_gram.sum() / (end - start)
        return val

# %%
n_bkps = 9  # there are 9 change points (10 text segments)

algo = rpt.Dynp(custom_cost=CosineCost(), min_size=2, jump=1).fit(vectorized_text)
predicted_bkps = algo.predict(n_bkps=n_bkps)

print(f"True change points are\t\t{TRUE_BKPS}.")
print(f"Detected change points are\t{predicted_bkps}.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [10], in <cell line: 4>()
#       1 n_bkps = 9  # there are 9 change points (10 text segments)
#       3 algo = rpt.Dynp(custom_cost=CosineCost(), min_size=2, jump=1).fit(vectorized_text)
# ----> 4 predicted_bkps = algo.predict(n_bkps=n_bkps)
#       6 print(f"True change points are\t\t{TRUE_BKPS}.")
#       7 print(f"Detected change points are\t{predicted_bkps}.")
#
# File ~/venv/lib/python3.9/site-packages/ruptures/detection/dynp.py:138, in Dynp.predict(self, n_bkps)
#     131 if not sanity_check(
#     132     n_samples=self.cost.signal.shape[0],
#     133     n_bkps=n_bkps,
#     134     jump=self.jump,
#     135     min_size=self.min_size,
#     136 ):
#     137     raise BadSegmentationParameters
# --> 138 partition = self.seg(0, self.n_samples, n_bkps)
#     139 bkps = sorted(e for s, e in partition.keys())
#     140 return bkps
#
# File ~/venv/lib/python3.9/site-packages/ruptures/detection/dynp.py:86, in Dynp.seg(self, start, end, n_bkps)
#      84 sub_problems = list()
#      85 for bkp in admissible_bkps:
# ---> 86     left_partition = self.seg(start, bkp, n_bkps - 1)
#      87     right_partition = self.seg(bkp, end, 0)
#      88     tmp_partition = dict(left_partition)
#
# File ~/venv/lib/python3.9/site-packages/ruptures/detection/dynp.py:86, in Dynp.seg(self, start, end, n_bkps)
#      84 sub_problems = list()
#      85 for bkp in admissible_bkps:
# ---> 86     left_partition = self.seg(start, bkp, n_bkps - 1)
#      87     right_partition = self.seg(bkp, end, 0)
#      88     tmp_partition = dict(left_partition)
#
#     [... skipping similar frames: Dynp.seg at line 86 (1 times)]
#
# File ~/venv/lib/python3.9/site-packages/ruptures/detection/dynp.py:86, in Dynp.seg(self, start, end, n_bkps)
#      84 sub_problems = list()
#      85 for bkp in admissible_bkps:
# ---> 86     left_partition = self.seg(start, bkp, n_bkps - 1)
#      87     right_partition = self.seg(bkp, end, 0)
#      88     tmp_partition = dict(left_partition)
#
# File ~/venv/lib/python3.9/site-packages/ruptures/detection/dynp.py:88, in Dynp.seg(self, start, end, n_bkps)
#      86 left_partition = self.seg(start, bkp, n_bkps - 1)
#      87 right_partition = self.seg(bkp, end, 0)
# ---> 88 tmp_partition = dict(left_partition)
#      89 tmp_partition[(bkp, end)] = right_partition[(bkp, end)]
#      90 sub_problems.append(tmp_partition)
#
# KeyboardInterrupt:

# %%
print(f"Detected change points are\t{predicted_bkps}.")
# Out:
# Detected change points are	[504, 507, 579, 751, 754, 1370, 1463, 1474, 1601, 1611].

# %%
true_segment_list = rpt.utils.pairwise([0] + TRUE_BKPS)
predicted_segment_list = rpt.utils.pairwise([0] + predicted_bkps)

for (n_paragraph, (true_segment, predicted_segment)) in enumerate(
    zip(true_segment_list, predicted_segment_list), start=1
):
    print(f"Paragraph n°{n_paragraph:02d}")
    start_true, end_true = true_segment
    start_pred, end_pred = predicted_segment

    start = min(start_true, start_pred)
    end = max(end_true, end_pred)
    msg = " ".join(
        f"{ind+1:02d}" if (start_true <= ind < end_true) else "  "
        for ind in range(start, end)
    )
    print(f"(true)\t{msg}")
    msg = " ".join(
        f"{ind+1:02d}" if (start_pred <= ind < end_pred) else "  "
        for ind in range(start, end)
    )
    print(f"(pred)\t{msg}")
    print()

# %%
for (start, end) in rpt.utils.pairwise([0] + predicted_bkps):
    excerpt = original_text[start:end]
    for (n_line, sentence) in enumerate(excerpt, start=start + 1):
        sentence = sentence.strip("\n")
        print(f"{n_line:>2}: {sentence}")
    print()
# Out:
# 620: What we were pitching was a private cloud system
# 621: Everybody knows about cloud computing now
# 622: It's like why your gmail account is available wherever you go
# 623: It's why facebook has this massive system of records for everyone everywhere
# 624: The government wanted to have these kind of capabilities
# 625: To dell ended up getting beat out by amazon
# 626: Some people aren't familiar with this
# 627: Many of them are, but amazon runs a secret cloud system for the government
# 628: I forget what they've rebranded it now, but there's this massive connection between industry and government in the classified space that just goes deeper and deeper and deeper and deeper
# 629: But at this point, I had misgivings because of what I'd seen in japan about government
# 630: But I was just trying to get by
# 631: I was trying to ignore the conflicts
# 632: I was trying to ignore the inconsistencies
# 633: And I think this is a state that a lot of people in these large institutions, not just in our country, but around the world, struggle with every day
# 634: They got a job, they got a family, they got bills
# 635: They're just trying to get by
# 636: And they know that some of the things they're doing are not good things
# 637: They know some of the things they're doing are actively wrong, but they know what happens to people who rock the boat
# 638: Eventually I changed my mind
# 639: And when I had gone to hawaii, which was the final position in my career with the intelligence community, because of an accident of history here, I wasn't supposed to be in this position at all
# 640: I was supposed to be at a group called the national threat operations center EndoC
# 641: But because of the way contracting works, and again, this is covered in the book, I end up being reassigned to this little rinky dink office that nobody's ever heard of in hawaii called the office of information sharing
# 642: And I'm replacing this old timer who's about to retire
# 643: Really nice guy, but he spent most of his days just reading novels and doing nothing and letting people be content to the fact or letting people forget that his office existed because he was the only one in it
# 644: There's a manager who's, like, over him, but it's actually over a larger group, and he just looks over him as sort of a favor
# 645: So now I come in, and now I'm the sole employee of the office of information sharing, but I'm not close enough to retirement that I'm okay with just doing nothing at all
# 646: So I get ambitious, and I come up with this idea for a new system called the heartbeat
# 647: And what the heartbeat is going to do is connect to basically every information repository in the intelligence community, both at the NSA and across network boundaries, which you normally can't cross
# 648: But because I've worked at both the CIA and the NSA, I knew the network well enough, both sides, that normal workers at the NSA would never have seen because you have to be in one or the other
# 649: I could actually connect these together
# 650: I could build bridges across this kind of network space and then draw all of these records into a new kind of system that was supposed to look at your digital ID, basically your sort of ID card that says, this is who I am
# 651: I work for this agency
# 652: I work in this office
# 653: These are my assignments, these are my group affiliations
# 654: And because of that, the system would be able to eventually aggregate records that were relevant to your job, that were related to you, and then it could provide them
# 655: And basically you could hit this site
# 656: It would be an update of what we used to call reboards, which were manually created
# 657: Then we go, look, you work in network defense, right? These are all the things that are happening on network defense
# 658: You work on, I don't know, economic takeovers in Guatemala
# 659: What's going on for you there? But in my off time, I helped the team that sat next to me, which was a systems administration team for Windows networks because I had been a Microsoft certified systems engineer, which means basically I knew how to take care of Windows networks
# 660: And this was all those guys did, and they always had way too much work, way too much work
# 661: And I had basically no work that I needed to do at all because all I was supposed to do was share information, which was not something that was particularly in demand because most people already knew what they wanted or what they needed
# 662: So it was basically my job was to sit there and collect a paycheck unless I wanted to get ambitious
# 663: I did some side gigs for these other guys, and one of them was running what we're called dirty word searches
# 664: Now, dirty word searches are let me dial this back because I know where this is hard to track
# 665: Everything that the NSA does in large part is classified
# 666: Everything the CIA does in large part is classified
# 667: If I made lunch plans with other people in my office, it was classified
# 668: That was the policy
# 669: It's dumb
# 670: This overclassification problem is one of the central flaws in government right now
# 671: This is the reason we don't understand what they're doing
# 672: This is why they can get away with breaking the law or violating our rights for so long, five years, ten years, 1550 years before we see what they were doing
# 673: And it's because of this routine classification, right? But every computer system has a limit on what level of classified information is supposed to be stored on it
# 674: And we've got all these complicated systems for code words and caveats that establish a system of what's called compartmentation
# 675: And this is the idea when you work at the CIA, when you work at the NSA, you're not supposed to know what's happening in the office next to you, right? Because you don't have need to know
# 676: Right? Again, that thing from the movies
# 677: And the reason they have this is they don't want one person to be able to go and know everything and tell everybody everything
# 678: They don't want anybody to know too much, particularly when they're doing lots of bad things, because then there's the risk that you realize they're doing so many bad things that it's past the point that we can justify, and they might develop sort of an ideological objection to that
# 679: Well, in the office of information sharing and actually, in basically every part of my career before that, I had access to everything
# 680: I had what was called a special caveat on my accesses called privacy, which means privileged access
# 681: What this means is you're kind of super user
# 682: Most people have all of these controls on the kind of information they can access, but I'm in charge of the system
# 683: People who need information, they have to get it from somewhere they don't know
# 684: Even the director of the CIA, right, he says, I need to know everything about this
# 685: He doesn't know where to get it
# 686: He's just a manager
# 687: Somebody has to be able to actually cross these thresholds and get those things
# 688: That guy was me
# 689: And so dirty word searches were these kind of automated queries that I would set up to go across the whole network and look at all of the different levels of classification and compartmentation and exceptionally controlled information
# 690: You can think of it as above top secret in these special compartments, right, where you're not even supposed to know what these compartments are for
# 691: You only know the code word unless you work in them, unless you have access to them, unless you read into them
# 692: Well, one day I got a hit on the dirty word search for a program that I'd never heard of called Stellar Wind
# 693: It came back because the little caveat for it, they're called handling Caveats, which is like, you can think of, like, burn after reading or For Your Eyes only
# 694: But this one's called Stlw, which means Stellar Wind
# 695: Unless you know what Stellar Wind is, you don't know how to handle it
# 696: All I knew was it wasn't supposed to be on my system
# 697: This is a little bit unusual
# 698: And it turned out this document was placed on the system because one of the employees who had worked on this program years before had come to Hawaii
# 699: And this person was a lawyer
# 700: I believe
# 701: And they had worked in the Inspector General's office
# 702: And they had compiled a report
# 703: Part of the Inspector General's report
# 704: Which is when the government is investigating itself into the operations and activities of this program
# 705: Well, this was the domestic mass surveillance program that I talked about in the very beginning of our conversation that started under the Bush White House
# 706: Stellar Wind was no longer supposed to be really an operation it had been unveiled in a big scandal in December 2005 in The New York Times by a journalist, James Rising
# 707: And I'm not going to name them because I don't want to get it wrong another journalist
# 708: You can look at the byline if you want to see their involvement, and there's a lot of history here, too
# 709: But what they had found was, of course, the Bush White House had constructed a warrantless wiretapping program, if you remember, the warrantless wiretapping scandal that was affecting everyone in the United States
# 710: Well, the Bush White House was really put in a difficult position by this scandal
# 711: They would have lost the election over this scandal because The New York Times actually had this story in October 2004, which was the election year
# 712: They were ready to go with it, but at the specific request of the White House, talking to the publisher of The New York Times, Salzburger, and Bill Keller, then the executive editor of The New York Times, the New York Times said we won't run the story because the president just said, if you run this story a month before the election, that's a very tight margin
# 713: If you recall, you'll have blood on your hands
# 714: And it was so close to 2001
# 715: The New York Times just went, you know what? Fine
# 716: Americans don't need to know that the Constitution is being violated
# 717: They don't need to know that the Fourth Amendment doesn't mean what they think it means
# 718: If the government says it's all right and it's a secret and you shouldn't know about it, that's fine
# 719: Now, December 2005, why did that change? Why did the New York Times suddenly run this story? Well, it's because James Rison, the reporter who found this story, had written a book, and he was about to publish this book
# 720: And The New York Times was about to be in a very uncomfortable position of having to explain why they didn't run this story and how they got scooped by their own journalists
# 721: And so they finally did it, but it was too late
# 722: Bush had been reelected, and now it was sweeping up the broken glass of our lost rights
# 723: So Congress, the Bush White House, was very effective and as I said before, telling a very few select members of Congress that this program existed, and they told them this program existed in ways that they wouldn't object to, but made them culpable for hiding the existence from the program, the existence of the program from the American people
# 724: And this is why someone like Nancy Pelosi, who you wouldn't exactly think would be buddy buddy with George Bush, was completely okay in defending this kind of program
# 725: In fact, later she said, oh, well, she had objections to the program that she wrote in a letter to the White House, but she never showed us the letter
# 726: She went, oh, well, that was classified, right
# 727: And this is not to bag on her individually
# 728: It's just she's a great example in here and not named example
# 729: Everyone knows of how this process works
# 730: The White House will implicate certain very powerful members of Congress in their own criminal activity
# 731: And so then when the White House gets in trouble for it, the Congress has to run cover for the White House
# 732: And so what happened was Congress passed an emergency law in 2007 called the Protect America Act, which should have been our first indication this is a very bad thing because they never name a law something like that unless something terrible
# 733: And what it did was it retroactively immunized all of the phone companies in the United States that had been breaking the law millions of times a day by handing your records over to the government
# 734: Which they weren't allowed to do simply on the basis of a letter from the President saying
# 735: Please do this
# 736: And these companies went
# 737: Look
# 738: Now that we've been uncovered
# 739: Now that we've been shown that we're breaking or now that these journalists have shown that we've broken the law and violated the rights of Americans on a staggering scale that could bankrupt our companies because we can be sued for this
# 740: We will no longer cooperate with you unless you pass a law that says people can't sue us for having done this
# 741: And so we get the Protect America Act, which is an emergency
# 742: This is all public history too
# 743: Yeah, you can look this up on Wikipedia
# 744: And so then they go, it's an emergency law
# 745: We have to pass this now
# 746: We have to keep this program active
# 747: Bush is going to end the warrantless wiretapping program and continue it under this new authority where it's going to have some special level of oversight and these kind of things eventually
# 748: But for now, we just have to make sure people are safe again
# 749: They go to fear
# 750: They say, if we don't have this program, terrorist attacks will continue
# 751: People will die
#
# 752: Blood on your hands
# 753: Blood on your hands
# 754: Blood on your hands
#
# 755: Think of the Children protect America act passes
# 756: The companies get off the hook
# 757: The bush white House gets off the hook
# 758: The Congress that was then sharing in criminal culpability for authorizing or rather letting these things go by without stopping them, then passes in 2008 the Foreign Intelligence Surveillance Act Amendments of 2008
# 759: This is called the FAA FISA Menu Act of 2008
# 760: And rather than stopping all of the unlawful and sort of unconstitutional activities that the intelligence agency was doing, they continued it in different ways simply by creating a few legal hoops for them to jump through
# 761: Now, this is not to say these things aren't helpful at all
# 762: It's not to say they're not useful at all
# 763: But it's important to understand when the government's response to any scandal, and this applies to any country, is not two of the person who is caught breaking the law comply with the law but instead make the activities of the person who is breaking the law legal
# 764: Right
# 765: They make the law comply with what the agencies want to do rather than make the agencies comply with the law
# 766: That's a problem
# 767: And that's what happened here
# 768: Now, the intelligence community's powers actually grew in response to this scandal in 2008 because Congress was on the hook and they just wanted to move on and get this over with
# 769: There were objections
# 770: There were people who knew this was a bad idea, but it didn't pass on
# 771: Now, what the public took away from this because a part of these laws was a requirement, that the Inspector general of all of these different intelligence community elements and the Director of National Intelligence submit a report saying, this is what happened under that warrantless wiretapping program
# 772: This is how it complied with the law or how it didn't comply with the law
# 773: And basically look back at how this program was constituted, what it did, what the impacts and effects were
# 774: And that was supposed to be sort of the Truth and Reconciliation Council right? Now, why am I talking about all this ancient history? Well, I'm sitting here in 2012 with a classified Inspector General's draft report from the NSA
# 775: The names
# 776: Names? That says Dick Cheney
# 777: This says David Addington
# 778: This is Nancy Pelosi
# 779: This is all these people who are involved in the program, the ticktok of how it happens
# 780: It says the director of the NSA, the guy who was evacuating the building at the beginning of our podcast here, that guy was asked by the President of the United States if he would continue this program after being told by the White House and the Department of justice that these programs were not lawful, that they were not constitutional
# 781: And the President said, would you continue this program on my say so alone, knowing that it's risky, knowing that it's unlawful? And he said, yes, sir, I will if you think that's what's necessary to keep the country safe
# 782: And at that moment, I realized these guys don't care about the law
# 783: These guys don't care about the Constitution
# 784: These guys don't care about the American people
# 785: They care about the continuity of government
# 786: They care about the state
# 787: Right? And this is something that people have lost
# 788: We hear this phrase over and over again, national security
# 789: National security, national security
# 790: And we're meant to interpret that to mean public safety
# 791: But national security is a very different thing from public safety
# 792: National security is a thing that in previous generations we refer to as state security
# 793: National security was a kind of term that came out of the Bush administration to run cover for the fact that we were elevating a new kind of secret police across the country
# 794: And what does it mean, again, in a democracy in the United States, the public is not partner to government
# 795: The public does not hold the leash of government anymore
# 796: But we are subject to government, right? We are subordinate to government, and we're not even allowed to know that it happened
# 797: Now, in the book, I tell the fact that I had access to the unclassified version of this report back in Japan
# 798: And what's interesting is the unclassified version of the report, and we've all seen this today with things like the Mueller report and all of the intelligence reporting that's happened over the last several years
# 799: When the government provides a classified report to the public, it's normally the same document, the unclassified version, the classified version of the same thing
# 800: It's just the Unclassified version has things blacked out or redacted that they say, oh, you're not allowed to know this sentence or this paragraph or this page or whatever
# 801: The document that the public had been given about the warrantless wiretapping program was a completely different document
# 802: It was a document tailor made to deceive and mislead the Congress and the public of the United States
# 803: And it was effective in doing that
# 804: And in 2012, what I realized was this is what real world conspiracies look like, right? It doesn't have to be smoking men behind closed doors
# 805: It's lawyers and politicians
# 806: It's ordinary people from the working level to the management level who go, if we don't explain this in a certain way, we're all going to lose our jobs or the other way they go, we're going to get something out of this if we all work together
# 807: Civilization is the history of conspiracy, right? What is civilization but a conspiracy for all of us to do better by working together? But it's this kind of thing that I think too often we forget because it's boring as hell
# 808: I want all your listeners, right, to go to the Washington Post because this document that I discovered that really changed me has been published courtesy of the Washington Post
# 809: It's called the Inspector General's Report on Stellar Wind
# 810: And you can look at the actual document that I saw that was unredacted, right? I had no blacked out pages on mine
# 811: And what I believe it shows is that some of the most senior officials in the United States, elected and unelected, worked together to actively undermine the rights of the American people to give themselves expanded powers
# 812: Now, in their defense, they said they were seeking these powers for a good and just and noble cause
# 813: They say they were trying to keep us safe
# 814: But that's what they always say
# 815: That's what every government says
# 816: That's no different than what the Chinese government says or the Russian government says
# 817: And the question is, if they are truly keeping us safe, why wouldn't they simply just tell us that? Why wouldn't they have that debate in Congress? Why wouldn't they put that to a vote? Because if they were, and they could convince us that they were, they'd win the vote
# 818: And particularly we all know, like the Patriot act passed
# 819: One of the worst pieces of legislation in modern history passed
# 820: Why didn't we get a vote? And I think if you read the report, the answer will be clear
# 821: So I'm sorry, Joe, I went on for very long
# 822: No, it was amazing
# 823: Don't apologize at all
# 824: It's just completely fascinating that the continuation of this policy came down to one man and the president having this discussion that is much more but literally the president at the heart of it
# 825: Yes, at the heart of it in every expression of executive power, right? And by executive, we mean the white house here, the CIA, the NSA, the FBI, the DOJ, right? These guys exist as a part of the executive branch of government in a real way
# 826: They work for the white house
# 827: Now, there are laws and regulations and policies that are supposed to say they're supposed to do this and they're supposed to say they're not supposed to do that
# 828: But when you look at federal regulations, when you look at policies as an employee of government, when you violate these policies, the worst thing that happens to you is you lose your job because there's no criminal penalty for the violation of these laws
# 829: And so it's very easy for people who exist in these structures, particularly at the very top levels of these structures, to go, look, we have a given set of lawful authorities, and these are defined very broadly to give us leeway, to do whatever it is we think is proper and appropriate and just
# 830: Now take that proper and appropriate just from the perspective of any given individual, right, any given president
# 831: Now intersect that with what's good for them politically, and that's where problems begin to arise
# 832: Now, the safety measure that's supposed to protect us from this in the US
# 833: System and democracy broadly is these people are supposed to be what are called public officials
# 834: That means we know their decisions
# 835: That means we know their policies
# 836: That means we know their programs and prerogatives and powers like what they are doing both in our name and what they're doing against us
# 837: And because they are transparent to us, we the people, can then police their activities
# 838: We can go, I disagree with this
# 839: We can protest it, we can campaign against it, right? We can try to become the president, do whatever
# 840: They are public officials, and we are private citizens
# 841: They're not supposed to know anything about us, right? Because we, in relative terms, hold no power, and they hold all the power
# 842: So they have to be under the tightest constraints we need to be in the freest circumstances
# 843: And yet the rise of the state secrets doctrine, this whole classification system that goes all the way back to last century, about the middle of the last century, I believe, is when it really started getting test in court
# 844: And I think you know more about this in many cases than I do
# 845: When you start talking about what happened in the FBI and the CIA and the NSA's sort of old dirty work in the 20th century, they abused their powers repeatedly and continuously
# 846: They did active harm to domestic politics in the United States
# 847: The FBI was spying on Martin Luther King and trying to get Martin Luther King to kill himself before the Nobel Prize was going to be awarded
# 848: In fact, after MLK gave his I Have a Dream speech two days later, the FBI classified him as the greatest national Earth
# 849: I think it was the greatest national security threat in the United States
# 850: And yet this is the FBI
# 851: This is the group that everybody's applauding today saying all these wonderful patriots and heroes
# 852: Now, I'm not saying everybody the FBI is bad
# 853: I'm not saying everybody at the CIA and the NSA is bad
# 854: I'm saying that you don't become patriot based on where you work
# 855: Patriotism is not about loyalty to government
# 856: Patriotism, in fact, it's not about loyalty to anything
# 857: Patriotism is a constant effort to do good for the people of your country, right? It's not about the government
# 858: It's not about the state
# 859: We'll get into loyalty later because I think one of the big criticisms against me that should be talked about is they go, look, this guy is disloyal
# 860: He broke an oath
# 861: He did whatever
# 862: Loyalty is a good thing when it's in the service of something good, but it is only good when it's in the service of something good
# 863: If you're loyal to a bad person, if you're loyal to a bad program, if you're loyal to a bad government, that loyalty is actively harmful
# 864: And I think that's overlooked
# 865: But, yeah, when you get back into this whole thing about sort of where it came from, why it happened, how it could come out of just this small group, and then they could slowly kind of poison by implication, by complicity, by bringing them into the conspiracy and then having them not say anything about it, a wider and wider broad body of people
# 866: And then once you've got enough people in on it, it's much easier to convince other people that it's legitimate because they can go, look, we've got 30 people who know about this, and none of them have objected to it
# 867: Why are you going to object to this? All of this derives from the original sin, which is, in a democracy, creating a system of government that is, in fact, a secret government, a body of secret law, a body of secret policy that is far beyond what legitimate government secrets could be
# 868: This is not to say, like, government can have no secrecy at all if the government wants to investigate someone without having them respond, right? We're talking traditional law enforcement
# 869: Sure you're not going to tell this mobster, hey, we're going to start investigating you
# 870: We, the public, don't need to know the names of every terrorist
# 871: Suspect out in the world, right? But we do need to know again the powers and programs, the policies that the government is asserting, at least the broad outlines of it, because otherwise, how can we control it? How do we know if the government is applying its authorities that are supposed to be granted to it by us if we don't know what it is that they're doing? This is the main thing
# 872: And really the story behind the title Permanent Record is, look, Joe, when I was a kid, when you were a teenager running, like, what's the worst thing you ever said? Did you say anything you weren't proud of? Did you do anything that you weren't proud of? Something that today, in, like the wokeest of Twitterland, you would get in trouble for, I'm sure
# 873: And that's right
# 874: One of the horrible things about kids growing up today is that they do have all this stuff out there on social media forever, and they can be judged horribly by something they did when they were 13
# 875: It's exactly that
# 876: Our worst mistakes are our deepest shames were forgotten
# 877: They were lost
# 878: They were ephemeral
# 879: Even the things we did get caught for, they were known for a time
# 880: Maybe they're still remembered by people who are closest to us, whether we like them or dislike them
# 881: But there were people connected to us
# 882: Now we're forced to live in a real way, naked before power
# 883: Whether we're talking about Facebook, whether we're talking about Google, whether we're talking about the government of any country, they know everything about us, or much about us, rather, and we know very little about them, and we're not allowed to know more
# 884: Everything that we do now lasts forever, not because we want to remember, but because we're not allowed to forget
# 885: Just carrying a phone in your pocket is enough for your movements to be moralized, because every cell phone tower that you pass is keeping a record of that
# 886: And at and T keeps those records going back to 2008 under a program called Hemisphere
# 887: If you search for Hemisphere and at and T, you'll get a story in the Daily Beast about it
# 888: At Amp
# 889: T keeps your phone records going back to if any of your listeners were born after 1983, right? Born after me
# 890: Or it might be 1987, if they were born after 1987 and they're an at and T customer, or their calls across ATC's network
# 891: At and T has every phone call they ever made, rather the record that it happened, not necessarily the content that's on the phone call
# 892: Let me turn this around for you, Joe, because I feel like I've just been given a speech
# 893: When you look at this stuff, right, when you look at what's happening with government, when you look at what's happening with the Trump White House, the Obama White House, the Bush White House, you could see this trend happening
# 894: When you look at what's happening with Facebook
# 895: When you look at what's happening with Google, when you look at the fact that you go to every restaurant today and you see people looking at phones, you get on a bus, you get on a subway, you see somebody sitting next to you in traffic, you see people looking at phones
# 896: These devices are connected all the time now
# 897: People are getting Alexa right now
# 898: People have OK, Google, they have Siri on their phones that are in their house
# 899: They've always got these connected microphones
# 900: Where do you think this leads, and what is it that gives you sort of trust in the system, faith in the system
# 901: So we can start a conversation here
# 902: What strikes you about this? Well, it's completely alien and it's new
# 903: This is something that's unprecedented
# 904: We don't have a long human history of being completely connected via technology
# 905: This is something we're navigating right now for the first time
# 906: And it's probably the most powerful thing that the human race has ever seen in terms of the distribution of information
# 907: There's nothing that even comes close to it in all of human history
# 908: And we're figuring it out as we go along
# 909: And what you exposed is that not only are we figuring out as we go along, but that to cover their ass, the cell phone companies in cahoots with the government have made it legal for them to gather up all of your phone calls, all of your text messages, all of your emails, and store them somewhere
# 910: So that retroactively
# 911: If you ever say anything they don't like or do something they don't like, they can go back, find that, and use it against you
# 912: And we don't know who they are
# 913: We don't know why they're doing it, and we didn't know they could do it until you exposed it
# 914: The connection of human beings via technology is both amazing and powerful and incredible in terms of our access to knowledge, but terrifying in terms of the government's ability to track our movements, track your phone calls, track everything
# 915: And under the guise of protecting us from terrorists and protecting us from sleeper cells, protecting us from attacks, if they really are protecting us from these attacks, that's great, but there's no provision in the Constitution that allows any of this
# 916: And this is where it gets really squirrely, because they're making up the rules as they go along, and they're making up these rules
# 917: The way you're describing it is, step by step, this has happened to sort of protect their ass and keep themselves from being implicated in what has been a violation of our rights and our privacy and the Fourth Amendment
# 918: Yeah, I mean, I think one of the things that everybody needs to understand when you look at these things and the reason we talked about before when I got this information, why I didn't just put it on the Internet and people criticize me for this they go, I didn't share enough information because the journalists are gatekeeping, right? They've got a big archive, and they haven't published everything from it, and I told them not to publish everything from it
# 919: Why did you do that? Why did you do that? Again, it gets back to legitimate secrets and illegitimate secrets
# 920: Some spying
# 921: From my perspective, career spy is okay, right? Agreed
# 922: If you have hacked a terrorist phone and you're getting some information about that, useful
# 923: Agreed
# 924: Yeah
# 925: If you're spying on a Russian general in charge of a rocket division, useful
# 926: Right
# 927: But there are lines and degrees in that where it's not useful
# 928: Now, the examples that I just gave you, these are targeted
# 929: This is where you're spying on an individual they're known, named person that is being monitored for specific reason that is related, hopefully from a warranty, right? Well, even for foreign intelligence, in some indications, you don't need a warrant strictly, although I think they should have warrants for all of these investigations because they established a court for precisely this reason called the Foreign Intelligence Surveillance Court, right? And there's not a judge in the world who wouldn't stamp a warrant saying, hey, spy on Abu Jihad over here, right? And if you want to spy on another guy, boris Badanov of the rocket Division, right, that's okay
# 930: They're going to go with that
# 931: But then you look at these edge cases in the archive that I provided to journalists
# 932: There have been stories that have come out where they've spied on journalists, right? They've spied on human rights groups and these kind of things I think people miss
# 933: I'm going to throw up some slides here, so forgive me if this gets weird and I put up the wrong ones, but since I came forward, this Foreign Intelligence Surveillance Court that the government says authorized these programs 15 different times was overruled by the first open courts to look at the program
# 934: These are federal courts here, right, that said, no, actually, these programs are unlawful
# 935: They're likely unconstitutional
# 936: When you start looking at the facts, you see even within the context of the very loose restrictions and laws that apply to the NSA and surveillance, they say they broke their own laws 2776 times in a single year
# 937: And then you ask about that thing that motivates me, like why I came forward
# 938: We had been trying as a country before I came forward to prove the existence of these programs legally, because this is our means of last sort of recourse in our system
# 939: We got the executive, we got the legislature, we got the judiciary
# 940: So Congress makes the laws
# 941: The executive is supposed to carry them out
# 942: The courts are supposed to play referee
# 943: The executive had broken the laws
# 944: Congress was turning a blind eye to the laws, and the courts were
# 945: And this is just months before I came forward going, well, it does appear that the ACLU and Amnesty International like all of these human rights groups and nongovernmental organizations had established that these programs are likely unlawful
# 946: They likely exist, they're simply classified
# 947: But the government responded with this argument that you just saw
# 948: Saying that
# 949: Well
# 950: It's a state secret if they do exist
# 951: You
# 952: The plaintiffs
# 953: Don't have hard
# 954: Concrete evidence that they do exist
# 955: And the government is saying legally
# 956: You have no right to discover evidence from the government
# 957: Write documents
# 958: Demand documents
# 959: And demand and answers from the government as to whether or not these things exist
# 960: Because the government's just going to give its standard what they call global response
# 961: We can neither confirm nor deny that these things exist
# 962: Which leaves you out in the cold, which leaves the courts out in the cold
# 963: The courts go, look, the government could be breaking the law here
# 964: Look, they could be violating the constitution here, but because you can't prove it, and because the government doesn't want to play ball, and the government says if we were doing this, it would be legal and it would be necessary for national security or whatever, the court can't presume to know national security better than the executive because the courts aren't elected
# 965: And so this leads to this fundamentally broken system where, OK, the only way to have the courts review the legality of the programs is to establish the programs exist, but the programs are classified, so you can't establish they exist unless you have evidence
# 966: But providing that evidence to courts, to journalists, to anyone, is a felony
# 967: That's punishable by ten years per count under the espionage act
# 968: And the government has charged every source of public interest journalism who has really made a significant difference in these kind of cases since Daniel Ellsberg, really going back to that under the same espionage act, it's always the same law
# 969: And there's no distinction to government between whether you sold information to a foreign government for private benefit or whether you provided information only to journalists for the public interest
# 970: And then that's a fundamentally harmful thing
# 971: I think when you look at things that have come in the wake of this, we're talking about the post 2013 court rulings that found what the government was doing was unlawful
# 972: You see the courts saying actually that leaks, or air quotes leaks can actually be beneficial
# 973: Leak is used in the governance, and this is from a federal court
# 974: These are not exactly my biggest supporters
# 975: They're recognizing that although leak implies harm, it implies something that's broken
# 976: It's actually helpful
# 977: It's a leak that's letting in daylight in this context, that is the only thing that allows the system to operate in a context where one year before I came forward, we had the NSA saying this kind of stuff didn't happen
# 978: We had hang on this famous exchange, which more than anything made me realize this was a point of no return, because I told you this, you've heard this, but if you haven't seen it, you might not believe me, right? Maybe I'm a sketchy guy
# 979: Whatever
# 980: One of those senators I told you that objected to this stuff, that was doing the Lassie barks for all those years, ron Wyden was confronting the most senior spy in the United States, general James Clapper, who was then the Director of National Intelligence, right? There's no guy higher than him
# 981: The buck stops with him when it comes to intelligence
# 982: He's testifying under oath in front of Congress, right? But more broadly, in front of the public
# 983: This is televised
# 984: And Ron Wyden asked him a very specific question about a program, mind you, that Ron Wyden knows exists because he has security clearance
# 985: He sits on the Intelligence Committee, and he knows there's domestic mass surveillance
# 986: And this is how it goes
# 987: This is how the top spy responds under oath
# 988: So what I wanted to see is if you could give me a yes or no answer to the question, does the NSA collect any type of data at all on millions or hundreds of millions of Americans? No, sir, it does not
# 989: Not wittingly
# 990: There are cases where they could inadvertently, perhaps collect, but not willingly
# 991: So that was a lie
# 992: Widen knew it was a lie
# 993: Clapper knew it was a lie
# 994: He actually admitted it was a lie after I came forward three months later
# 995: But he said it was the least untruthful thing he could think of to say in the context of being in the hot seat there
# 996: But what does it mean for a democracy when you can lie under oath to Congress and the congressman even knows you're lying to them, but they're afraid to correct you? And Wyden, by the way, it wasn't a surprise
# 997: Widen gave him those questions 24 hours in advance, and he wrote a letter afterwards asking for Clapper to amend his testimony, right? Not even at a press conference, but just to say this was incorrect, whatever
# 998: So he could go through the legal process and show his fellow congressman that there was a problem and that they needed to do it
# 999: But all of that was refused to us
# 1000: All of it was denied to us
# 1001: And here I am sitting at the NSA next to my buddies, who I've talked to about these programs
# 1002: I've gone
# 1003: Look at this
# 1004: And they're laughing at it
# 1005: I'm laughing at it
# 1006: And it's not that we go, oh, ha ha, he's getting away with it
# 1007: It's like, what are you going to do? These guys are bullshitters
# 1008: The system is built on lies
# 1009: Even many people, many experts who have studied this know our lies
# 1010: But if you can't prove they are lies, how do you move beyond that? And that's really a question that has never been more relevant than I think it is today under the current White House
# 1011: So you're in this position where you have this information, and you know that these surveillance systems are in place and they are unconstitutional, and you feel this deep responsibility to let the American people know about this
# 1012: What makes you take the leap? So this is covered extensively in the book because it took a long time, I would imagine
# 1013: Yeah, right, exactly
# 1014: People like to think it's like a cinematic moment where I find this golden document like the Stellar Wind Report, and that's the closest thing to a smoking gun that exists
# 1015: But look, if you found that, you can read that later, look at that and imagine yourself being like, oh, I'm going to go outside on the courthouse steps and wave this thing and burn my life to the ground, burn my family to the ground
# 1016: I'm never going to be work again
# 1017: I'm going to jail for the rest of my life
# 1018: The question is, what would it take for you to light a match and burn your life to the ground? For a long time? The answer was nothing
# 1019: And I'm ashamed of that
# 1020: It took me so long to get over that home because I was waiting for somebody else to do it
# 1021: When I saw people like Ron Wyden on this, when I saw people like the court case that I showed before, where people were actively challenging these programs, right
# 1022: Journalists had the scent of it
# 1023: And there are a lot of people who are going to be in the YouTube comments or whatever and go, oh, I knew this was happening
# 1024: No, you didn't
# 1025: Well, Bill Bimini, you had Benny excuse me, bill Bini, he initially was the one that came out and spoke about this issue
# 1026: Yeah, bill Benny is part of, shall we say, the group of early NSA whistleblowers who came with Thomas Drake
# 1027: Bill benny Kirk Weby
# 1028: I believe in Ed Loomis
# 1029: And these guys all got their doors kicked in
# 1030: They got harassed by the FBI
# 1031: Tom Drake, who was a senior executive at the NSA, this is a guy who had a lot to lose, was charged under the same law was the Espionage Act
# 1032: And these guys who were doing it earlier during the Bush administration, some of them were talking to the journalists
# 1033: Maybe it's alleged
# 1034: I don't want to put them on the spot
# 1035: Maybe they deny it, maybe they don't
# 1036: Leave that to them
# 1037: But somebody somewhere was informing this reporting that got into the New York Times about the Bush era warrantless wiretapping program
# 1038: And eventually journalists put this out there
# 1039: People knew these capabilities existed
# 1040: But yes, then there's the person in the YouTube comments
# 1041: It's like, oh, we knew all about this
# 1042: It's nothing new
# 1043: And the thing is, you can know about some programs and not know about others
# 1044: You can have a suspicion
# 1045: You can know with certainty that this stuff is capable or it is possible the capability exists
# 1046: You can know that the government has done this stuff in the past
# 1047: You can know they are likely to do it again you can have all these indications
# 1048: You can have like the Jewel versus NSA case that's run by the EFF which is about at and T setting up secret rooms in their telecommunications facilities where they basically drag all the fibers for their domestic internet communications and like phone communications into a room that's purpose built for the NSA and then they bring it out
# 1049: But at and T denies it's
# 1050: The NSA, the NSA denies that these things happen or that are done at all
# 1051: Right? And so this is the context
# 1052: You say, you know and let's put it the other way maybe you do know, right? Maybe you are an academic researcher or maybe you're a technological specialist
# 1053: Maybe you're just somebody who reads all the reporting and you actually know you can't prove it but you know this is going on
# 1054: But that's the thing in a democracy the distance between speculation and fact, the distance between what you know and what you can prove to everybody else in the country is everything in our model of government
# 1055: Because what you know doesn't matter
# 1056: What matters is what we all know
# 1057: And the only way we can all know it is if somebody can prove it
# 1058: If you can prove it and if you don't have the evidence, you can't prove it
# 1059: And of course when we talk about the earlier stuff, right, like a more corporatized media, they've got 1000 incentives not to get involved in this stuff
# 1060: They need access to the White House
# 1061: They need these officials to sit down with them and give interviews, right? That's constant content that they need, that's access that they need
# 1062: They need to be taken seriously
# 1063: They need to be admitted to briefers
# 1064: It is a codependent relationship rather
# 1065: And so the only way to make sure people understand this broadly is if we all work together
# 1066: If we collectively can establish a corpus of evidence, a body of facts that is so large and so persuasive it overcomes the natural and understandable resistance of these more corporatized media groups
# 1067: It overcomes the political and partisan sort of loyalties that all of these political factions in the country do
# 1068: Where they go it's my president
# 1069: Even if I don't like this stuff, even if I don't agree with this stuff, I don't want to say it exists
# 1070: I want to deny it until it's proved in HD on video signing the order to do this or the other because otherwise there's a chance my guy might not get reelected
# 1071: And that's the only way this kind of stuff can happen
# 1072: And the sad fact is the opportunities that we have to prove this, like the moments in history where we do prove something, anything beyond a reasonable doubt are so few and so rare that they almost always only come from whistleblowers
# 1073: And I think that's one of the problems that we have, particularly in the climate movement
# 1074: Go ahead
# 1075: I'm sorry, did you take any comfort from knowing that Obama, when he was running for office and in his Hope and Change website, he had provisions to protect whistleblowers and provisions to reward people, right? I mean, do you remember all that? It was eventually redacted or eventually deleted
# 1076: It from the website, but that appeared
# 1077: It from Google, but that was a big part of his program, or what he was running on was that when people were exposing unlawful activity, he was going to protect those people
# 1078: Did you take any comfort in that? He also campaigned well, obama also during his campaign said he campaigned actively against the warrantless wiretapping, the Bush administration, because, remember, Bush is in the scandal
# 1079: The height of this in 2007
# ...
# 1446: Also, if they get me, I only trust phones so much, so there's only so much they can derive from the compromise
# 1447: And this is how operational security works
# 1448: You think about what are the realistic threats that you're facing that you're trying to mitigate? And the mitigation that you're trying to do is what would be the loss, what would be the damage done to you if this stuff was exploited? Much more realistic than worrying about these things that I call voodoo hacks, right, which are like next level stuff and actually just a shout out for those of your readers who are interested in this stuff
# 1449: I wrote a paper on this specific problem
# 1450: How do you know when a phone is actually off? How do you know when it's actually not? Spying on you with a brilliant, brilliant guy
# 1451: Named Andrew Bunny Huang
# 1452: He's an MIT PhD in, I think, electrical engineering called the introspection engine that was published in the journal of open engineering
# 1453: You can find it online, and it will go as deep down in the weeds, I promise you, as you want
# 1454: We take an iPhone six
# 1455: This was back when it was fairly new, and we modified it so we could actually not trust the device to report its own state, but physically monitor its state to see if it was spying on you
# 1456: But for average people, right, this academic, that's not your primary threat
# 1457: Your primary threats are these bulk collection programs
# 1458: Your primary threat is the fact that your phone is constantly squawking to these cell phone towers
# 1459: It's doing all of these things because we leave our phones in a state that is constantly on you're constantly connected, right? Airplane mode doesn't even turn off WiFi, really anymore
# 1460: It just turns off the cellular modem
# 1461: But the whole idea is we need to identify the problem
# 1462: And the central problem with smartphone use today is you have no idea what the hell it's doing at any given time
# 1463: Like, the phone has the screen off, you don't know what it's connected to, you don't know how frequently it's doing it
#
# 1464: Apple and iOS, unfortunately, makes it impossible to see what kind of network connections are constantly made on the device and to intermediate them going, I don't want Facebook to be able to talk right now
# 1465: I don't want google to be able to talk right now
# 1466: I just want my secure messenger app to be able to talk
# 1467: I just want my weather app to be able to talk
# 1468: But I just checked my weather, and now I'm done with it
# 1469: So I don't want that to be able to talk anymore
# 1470: And we need to be able to make these intelligent decisions on not just an app by app basis, but a connection by connection basis, right? Let's say you use Facebook because for whatever judgment we have, a lot of people might do it
# 1471: You want it to be able to connect to Facebook's content servers
# 1472: You want to be able to message a friend
# 1473: You want to be able to download a photograph or whatever, but you don't want it to be able to talk to an ad server
# 1474: You don't want it to talk to an analytics server that's monitoring your behavior, right? You don't want to talk to all these third party things because facebook crammed their garbage into almost every app that you download, and you don't even know what's happening because you can't see it
#
# 1475: Right? And this is the problem with the data collection used today, is there is an industry that is built on keeping this invisible
# 1476: And what we need to do is we need to make the activities of our devices, whether it's a phone, whether it's computer, or whatever, more visible and understandable to the average person and then give them control over it
# 1477: If you could see your phone right now, and at the very center of it is a little green icon that's your handset, or it's a picture of your face, whatever, and then you see all these little spokes coming off of it
# 1478: That's every app that your phone is talking to right now, or every app that is active on your phone right now and all of the hosts that it's connecting to
# 1479: And you can see right now, once every 3 seconds your phone is checking into Facebook and you could just poke that app and then boom
# 1480: It's not talking to Facebook anymore
# 1481: Facebook is not allowed
# 1482: Facebook speaking privileges have been revoked
# 1483: Right? You would do that? We would all do that
# 1484: If there was a button on your phone that said do what I want but not spy on me, you would press that button, right? That button does not exist right now
# 1485: And both Google and Apple, unfortunately Apple is a lot better at this than Google, but neither of them allow that button to exist
# 1486: In fact, they actively interfere with it because they say it's a security risk
# 1487: And from a particular perspective, they actually aren't wrong there
# 1488: But it's not enough to go, we have to lock that capability off from people because we don't trust they would make the right decisions
# 1489: We think it's too complicated for people to do this
# 1490: We think there's too many connections being made
# 1491: Well, that is actually a confession of the problem right there
# 1492: If you think people can't understand it, if you think there are too many communications happening, if you think there's too much complexity in there, it needs to be simplified
# 1493: Just like the President can't control everything like that
# 1494: If you have to be the President of the phone, and the phone is as complex as the United States government, we have a problem guys
# 1495: This should be a much more simple process
# 1496: It should be obvious
# 1497: And the fact that it's not, and the fact that we read story after story, year after year saying all your data has been breached here, this company is spying on you here, this company is manipulating your purchases or your search results, or they're hiding these things from your timeline, or they're influencing you or manipulating you in all of these different ways
# 1498: That happens as a result of a single problem
# 1499: And that problem is inequality of available information
# 1500: They can see everything about you, they can see everything about what your device is doing and they can do whatever they want with your device
# 1501: You on the other hand, owned the device
# 1502: Well, rather you paid for the device
# 1503: But increasingly these corporations own it
# 1504: Increasingly these governments own it
# 1505: And increasingly we are living in a world where we do all the work right, we pay all the taxes, we pay all the costs, but we own less and less and nobody understands this better than the youngest generation
# 1506: Well, it seems like our data became a commodity before we understood what it was
# 1507: It became this thing that's insanely valuable to Google and Facebook and all these social media platforms
# 1508: Before we understood what we were giving up, they were making billions of dollars
# 1509: And then once that money is being earned, and once everyone's accustomed to the situation, it's very difficult to pull the reins back
# 1510: It's very difficult to turn that course around precisely because the money then becomes power, right
# 1511: The information then becomes influence
# 1512: That also seems to be the same sort of situation that would happen with these mass surveillance states
# 1513: Once they have the access, it's going to be incredibly difficult for them to relinquish that
# 1514: Right, yeah
# 1515: No, you're exactly correct
# 1516: And this is the subject of the book
# 1517: This is the permanent record, and this is where it came from
# 1518: This is how it came to exist
# 1519: The story of our lifetimes is how intentionally, by design, a number of institutions, both governmental and corporate, realized it was in their mutual interest to conceal their data collection activities, to increase the breadth and depth of their sensor networks that were sort of spread out through society
# 1520: Remember back in the day, intelligence collection in the United States, even at Sigma, used to mean sending an FBI agent to put alligator clips on an embassy building or sending in somebody disguised as a workman and they put a bug in a building
# 1521: Or they built a satellite listening site, right? We call these foreign sat or foreign satellite collection
# 1522: We're out in the desert somewhere
# 1523: They built a big parabolic collector, and it's just listening to satellite emissions, right? But these satellite emissions, these satellite links were owned by militaries
# 1524: They were exclusive to governments, right? It wasn't affecting everybody broadly
# 1525: All surveillance was targeted because it had to be
# 1526: What changed with technology is that surveillance could now become indiscriminate
# 1527: It could become dragnet, it could become bulk collection, which should become one of the dirtiest phrases in the language, if we have any kind of decency
# 1528: But we were intentionally this was intentionally concealed from us, right? The government did it
# 1529: They used classification, companies did it
# 1530: They intentionally didn't talk about it
# 1531: They denied these things were going, they said, you agreed to this and you didn't agree to nothing like this, I'm sorry, right? They go, we put that terms of service page up, and you click that
# 1532: You clicked a button that said, I agree, because you were trying to open an account so you could talk to your friends
# 1533: You were trying to get driving directions, you were trying to get an email account
# 1534: You weren't trying to agree to some 600 page legal form
# 1535: Even if you read, you wouldn't understand
# 1536: And it doesn't matter even if you did understand, because one of the very first paragraphs and it said, this agreement can be changed at any time unilaterally without your consent by the company, right? They have built a legal paradigm that presumes records collected about us do not belong to us
# 1537: This is sort of one of the core principles on which mass surveillance, from the government's perspective in the United States is legal
# 1538: And you have to understand that all the stuff we talked about today, the government says everything they do is legal, right? And they go, so it's fine
# 1539: Our perspective as the public should be, well, that's actually the problem, because this isn't, okay? The scandal isn't how they're breaking the law
# 1540: The scandal is that they don't have to break the law
# 1541: And the way they say they're not breaking the law is something called the third party doctrine
# 1542: A third party doctrine is a legal principle derived from a case in, I believe, the 1970s called Smith versus Maryland
# 1543: And Smith was this knucklehead who was harassing this lady, making phone calls to her house
# 1544: And when she would pick up, he just, I don't know, sit there, heavy breathing, whatever, like a classic creeper
# 1545: And it's terrifying, this poor lady
# 1546: So she calls the cops and says, one day I got one of these phone calls, and then I see this car creeping past my house on the street, and she got a license plate number
# 1547: So she goes to the cops, and she goes, Is this the guy? And the cops again, they're trying to do a good thing here
# 1548: They look up his license plate number, and they find out where this guy is, and then they go, well, what phone number is registered to the house? And they go to the phone company, and they say, can you give us this record? And the phone company says, yeah, sure, and it's the guy
# 1549: The cops got their man, right? So they go arrest this guy, and then in court, his lawyer brings all this stuff up, and they go, you did this without a warrant
# 1550: So that was the problem, was they went to the phone company and they got the records without a warrant
# 1551: They just asked for it, or they subpoenaed it, some lower standard of legal review, and the company gave it to him and got the guy
# 1552: They marched him off to jail, and they could have gotten a warrant, right? But it was just expedient
# 1553: They just didn't want to take the time
# 1554: The small town cops, you can understand how it happens
# 1555: They know the guy's a creeper
# 1556: They just want to get them off to jail
# 1557: And so they made a mistake
# 1558: The government doesn't want to let it go
# 1559: They fight on this, and they go, they weren't his records
# 1560: And so because they didn't belong to him, he didn't have a Fourth Amendment right to demand a warrant be issued for them
# 1561: They were the company's records, and the company provided them voluntarily, and hence, no warrant was required because you can get whatever you want without a warrant as long as it's yours
# 1562: Now, here's the problem
# 1563: The government extrapolated a principle in a single case of a single known, suspected criminal who they had real good reasons to suspect was their guy, and use that to go to a company and get records from them and establish a precedent
# 1564: These records don't belong to the guy, they belong to the company
# 1565: And then they said, well, if one person doesn't have a Fourth Amendment interest in records held by a company, no one does
# 1566: And so the company then has absolute proprietary ownership of all of these records about all of our lives
# 1567: And remember, this is back in the 1970s
# 1568: The Internet hardly exists in these kind of contexts
# 1569: Smartphones don't exist
# 1570: Modern society, modern communications don't exist
# 1571: This is the very beginning of the technological era
# 1572: And flash forward now 40 years, and they are still relying on this precedent about this one pervy creeper to go
# 1573: Nobody has a privacy right for anything that's held by a company
# 1574: And so long as they do that, companies are going to be extraordinarily powerful and they're going to be extraordinarily abusive
# 1575: And this is something that people don't get
# 1576: They go, oh, well, it's data collection, right? They're exploiting data
# 1577: This is data about human lives
# 1578: It is data about people
# 1579: These records are about you
# 1580: It's not data that's being exploited
# 1581: It's people that are being exploited
# 1582: It's not data that's being manipulated
# 1583: It's you that's being manipulated
# 1584: And this is something that I think a lot of people are beginning to understand
# 1585: The problem is the companies and the governments are still pretending they don't understand or disagreeing with this
# 1586: And this reminds me of something that one of my old friends, john Perry Barlow, who served with me at the Freedom of the Press Foundation I'm the president of the board, used to say to me, which is, you can't awaken someone who's pretending to be asleep
# 1587: He said it's an old Native American thing
# 1588: That's a great expression
# 1589: I think that's a good way to end this
# 1590: Ed, thank you very much for doing this
# 1591: I really appreciate it
# 1592: Please tell everybody the title of your book, and it's available right now
# 1593: Sure
# 1594: Yes, it is
# 1595: It's on shelves everywhere, at least until the government finds some other way to ban it
# 1596: It is called Permanent Record, and I hope you will read it
# 1597: I will read it, and I think what you've done is incredibly brave, and I think you're a very important part of history
# 1598: I think when all is said and done, what you did and what you exposed is going to change the way we view mass surveillance, change the way we view government oversight, and change the way we view the distribution of information
# 1599: I really think it's very important, and it was an honor to talk to you, man
# 1600: Thank you
# 1601: It was my pleasure
#
# 1602: Thank you so much for having me take care of yourself, man
# 1603: Stay safe
# 1604: No, don't stay safe
# 1605: Stay safe
# 1606: Open
# 1607: Stay free
# 1608: Open the possibility
# 1609: Take care
# 1610: Bye
# 1611: Take care.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=42b72ec6-04a6-4083-9286-1ab690f9f57d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
